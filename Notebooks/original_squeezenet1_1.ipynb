# %% [markdown]
# # Code for the paper:
#
# ## Efficient and Mobile Deep Learning Architectures for Fast Identification of BacterialStrains in Resource-Constrained Devices
#
# ### Architecture: SqueezeNet 1.0
# ### Data: Original + Cross-Validation

# %% [markdown]
# #### Loading libraries

# %%
# Imports here
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import torch.nn.functional as F
import pandas as pd
import time
import numpy as np

from PIL import Image
from sklearn.metrics import f1_score, precision_score, recall_score, classification_report
from sklearn.model_selection import KFold
from torch import nn
from torch import optim
from torch.utils.data import SubsetRandomSampler
from torchvision import datasets, transforms, models
from pytorch_model_summary import summary

# Archs not in Pytorch
from efficientnet_pytorch import EfficientNet

# External functions
from scripts.utils import *

# %%
print(torch.__version__)

import sys
print(sys.version)
# Out:
# 1.5.1
# 3.8.5 (default, Jul 28 2020, 12:59:40)
# [GCC 9.3.0]

# %% [markdown]
# ## Data paths and hyperparameters

# %% [markdown]
# #### Hyperparameters and dataset details.

# %%
# Dataset details
dataset_version = 'original' # original or augmented
img_shape = (224,224)
img_size = str(img_shape[0])+"x"+str(img_shape[1])

# Root directory of dataset
data_dir = '/home/yibbtstll/venvs/pytorch_gpu/CySDeepBacterial/Dataset/DIBaS/'

train_batch_size = 32
val_test_batch_size = 32
feature_extract = False
pretrained = True
h_epochs = 15
kfolds = 10

# %% [markdown]
# ## Data preparation and loading

# %% [markdown]
# #### Defining transforms and creating dataloaders

# %%
# Define transforms for input data
training_transforms = transforms.Compose([transforms.Resize((224,224), Image.LANCZOS),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406], 
                                                               [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
total_set = datasets.ImageFolder(data_dir, transform=training_transforms)

# Defining folds
splits = KFold(n_splits = kfolds, shuffle = True, random_state = 42)

# %% [markdown]
# #### Visualizing the target classes in dataset

# %%
train_labels = {value : key for (key, value) in total_set.class_to_idx.items()}
    
print(len(train_labels)) 
print(train_labels)
# Out:
# 32
# {0: 'Acinetobacter.baumanii', 1: 'Actinomyces.israeli', 2: 'Bacteroides.fragilis', 3: 'Bifidobacterium.spp', 4: 'Clostridium.perfringens', 5: 'Enterococcus.faecalis', 6: 'Enterococcus.faecium', 7: 'Escherichia.coli', 8: 'Fusobacterium', 9: 'Lactobacillus.casei', 10: 'Lactobacillus.crispatus', 11: 'Lactobacillus.delbrueckii', 12: 'Lactobacillus.gasseri', 13: 'Lactobacillus.jehnsenii', 14: 'Lactobacillus.johnsonii', 15: 'Lactobacillus.paracasei', 16: 'Lactobacillus.plantarum', 17: 'Lactobacillus.reuteri', 18: 'Lactobacillus.rhamnosus', 19: 'Lactobacillus.salivarius', 20: 'Listeria.monocytogenes', 21: 'Micrococcus.spp', 22: 'Neisseria.gonorrhoeae', 23: 'Porfyromonas.gingivalis', 24: 'Propionibacterium.acnes', 25: 'Proteus', 26: 'Pseudomonas.aeruginosa', 27: 'Staphylococcus.aureus', 28: 'Staphylococcus.epidermidis', 29: 'Staphylococcus.saprophiticus', 30: 'Streptococcus.agalactiae', 31: 'Veionella'}

# %% [markdown]
# ## Model definition and inicialization

# %% [markdown]
# #### Freezing pre-trained parameters, finetunning the classifier to output 32 classes.

# %%
# Freeze pretrained model parameters to avoid backpropogating through them
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        print("Setting grad to false.")
        for param in model.parameters():
            param.requires_grad = False
    
    return model

def get_device():
    # Model and criterion to GPU
    if torch.cuda.is_available():
        return 'cuda'
    else:
        return 'cpu'

# %%
models.squeezenet1_1(pretrained=False)
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (6): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (9): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 1000, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )

# %%
def load_model():
    # Transfer Learning
    model = models.squeezenet1_1(pretrained=pretrained)
    
    # Mode
    model = set_parameter_requires_grad(model, feature_extract)
    
    # Fine tuning
    # Build custom classifier
    # Build custom classifier
    model.classifier[1] = nn.Conv2d(512, 32, 
                                kernel_size=(1,1), stride=(1,1))
    return model

def create_optimizer(model):
    # Parameters to update
    params_to_update = model.parameters()

    if feature_extract:
        params_to_update = []
        for param in model.parameters():
            if param.requires_grad == True:
                params_to_update.append(param)

    else:
        n_params = 0
        for param in model.parameters():
            if param.requires_grad == True:
                n_params += 1


    # Loss function and gradient descent

    criterion = nn.CrossEntropyLoss()

    optimizer = optim.Adam(params_to_update, 
                          lr=0.001, 
                          weight_decay=0.000004)
    
    return criterion.to(get_device()), model.to(get_device()), optimizer

# %% [markdown]
# ## Training, validation and test functions

# %%
# Variables to store fold scores
train_acc = []
test_top1_acc = []
test_top5_acc = []
test_precision = []
test_recall = []
test_f1 = []
times = []

for fold, (train_idx, valid_idx) in enumerate(splits.split(total_set)):
    
    start_time = time.time()
    
    print('Fold : {}'.format(fold))
    
    # Train and val samplers
    train_sampler = SubsetRandomSampler(train_idx)
    print("Samples in training:", len(train_sampler))
    valid_sampler = SubsetRandomSampler(valid_idx)
    print("Samples in test:", len(valid_sampler))
    
    # Train and val loaders
    train_loader = torch.utils.data.DataLoader(
                      total_set, batch_size=train_batch_size, sampler=train_sampler)
    valid_loader = torch.utils.data.DataLoader(
                      total_set, batch_size=1, sampler=valid_sampler)
    
    device = get_device()
    
    criterion, model, optimizer = create_optimizer(load_model())
    
    # Training
    for epoch in range(h_epochs):
        
        model.train()
        running_loss = 0.0
        running_corrects = 0
        trunning_corrects = 0
        
        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                
            running_loss += loss.item() * inputs.size(0)
            running_corrects += (preds == labels).sum()
            trunning_corrects += preds.size(0)
            

        epoch_loss = running_loss / trunning_corrects
        epoch_acc = (running_corrects.double()*100) / trunning_corrects
        train_acc.append(epoch_acc.item())
        
        print('\t\t Training: Epoch({}) - Loss: {:.4f}, Acc: {:.4f}'.format(epoch, epoch_loss, epoch_acc))
        
        # Validation
        
        model.eval()  
        
        vrunning_loss = 0.0
        vrunning_corrects = 0
        num_samples = 0
        
        for data, labels in valid_loader:
            
            data = data.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            
            with torch.no_grad():
                outputs = model(data)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                
            vrunning_loss += loss.item() * data.size(0)
            vrunning_corrects += (preds == labels).sum()
            num_samples += preds.size(0)
            
        vepoch_loss = vrunning_loss/num_samples
        vepoch_acc = (vrunning_corrects.double() * 100)/num_samples
        
        print('\t\t Validation({}) - Loss: {:.4f}, Acc: {:.4f}'.format(epoch, vepoch_loss, vepoch_acc))
    
    # Calculating and appending scores to this fold
    model.class_to_idx = total_set.class_to_idx
    scores = get_scores(model, valid_loader)
    
    test_top1_acc.append(scores[0])
    test_top5_acc.append(scores[1])
    test_precision.append(scores[2])
    test_recall.append(scores[3])
    test_f1.append(scores[4])
    
    time_fold = time.time() - start_time
    times.append(time_fold)
    print("Total time per fold: %s seconds." %(time_fold))
# Out:
# Fold : 0
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.4969, Acc: 2.8239
# 		 Validation(0) - Loss: 3.4696, Acc: 4.4776
# 		 Training: Epoch(1) - Loss: 3.4255, Acc: 4.1528
# 		 Validation(1) - Loss: 3.4953, Acc: 0.0000
# 		 Training: Epoch(2) - Loss: 3.3677, Acc: 5.6478
# 		 Validation(2) - Loss: 3.3989, Acc: 2.9851
# 		 Training: Epoch(3) - Loss: 3.2932, Acc: 7.8073
# 		 Validation(3) - Loss: 3.4346, Acc: 1.4925
# 		 Training: Epoch(4) - Loss: 3.3071, Acc: 5.6478
# 		 Validation(4) - Loss: 3.3650, Acc: 5.9701
# 		 Training: Epoch(5) - Loss: 3.1392, Acc: 6.4784
# 		 Validation(5) - Loss: 3.2957, Acc: 5.9701
# 		 Training: Epoch(6) - Loss: 3.0170, Acc: 10.6312
# 		 Validation(6) - Loss: 3.0803, Acc: 7.4627
# 		 Training: Epoch(7) - Loss: 2.7584, Acc: 13.9535
# 		 Validation(7) - Loss: 2.7815, Acc: 14.9254
# 		 Training: Epoch(8) - Loss: 2.5780, Acc: 17.6080
# 		 Validation(8) - Loss: 2.6250, Acc: 26.8657
# 		 Training: Epoch(9) - Loss: 2.3974, Acc: 21.7608
# 		 Validation(9) - Loss: 2.6656, Acc: 10.4478
# 		 Training: Epoch(10) - Loss: 2.1737, Acc: 24.7508
# 		 Validation(10) - Loss: 2.8005, Acc: 17.9104
# 		 Training: Epoch(11) - Loss: 2.1121, Acc: 28.4053
# 		 Validation(11) - Loss: 1.9326, Acc: 34.3284
# 		 Training: Epoch(12) - Loss: 1.7748, Acc: 35.2159
# 		 Validation(12) - Loss: 1.9896, Acc: 25.3731
# 		 Training: Epoch(13) - Loss: 1.5071, Acc: 42.0266
# 		 Validation(13) - Loss: 1.8308, Acc: 34.3284
# 		 Training: Epoch(14) - Loss: 1.7022, Acc: 36.8771
# 		 Validation(14) - Loss: 1.5710, Acc: 35.8209
# Finished.
# Total time per fold: 316.6509048938751 seconds.
# Fold : 1
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.5267, Acc: 2.4917
# 		 Validation(0) - Loss: 3.4655, Acc: 4.4776
# 		 Training: Epoch(1) - Loss: 3.4659, Acc: 2.4917
# 		 Validation(1) - Loss: 3.4659, Acc: 0.0000
# 		 Training: Epoch(2) - Loss: 3.4538, Acc: 4.1528
# 		 Validation(2) - Loss: 3.4244, Acc: 0.0000
# 		 Training: Epoch(3) - Loss: 3.4051, Acc: 6.1462
# 		 Validation(3) - Loss: 3.8609, Acc: 7.4627
# 		 Training: Epoch(4) - Loss: 3.1563, Acc: 6.6445
# 		 Validation(4) - Loss: 3.0912, Acc: 8.9552
# 		 Training: Epoch(5) - Loss: 2.9145, Acc: 9.9668
# 		 Validation(5) - Loss: 2.8676, Acc: 8.9552
# 		 Training: Epoch(6) - Loss: 2.5413, Acc: 18.9369
# 		 Validation(6) - Loss: 2.6544, Acc: 10.4478
# 		 Training: Epoch(7) - Loss: 2.4421, Acc: 22.2591
# 		 Validation(7) - Loss: 2.4847, Acc: 17.9104
# 		 Training: Epoch(8) - Loss: 2.1116, Acc: 29.0698
# 		 Validation(8) - Loss: 1.9570, Acc: 40.2985
# 		 Training: Epoch(9) - Loss: 1.9379, Acc: 34.0532
# 		 Validation(9) - Loss: 1.6977, Acc: 46.2687
# 		 Training: Epoch(10) - Loss: 1.6047, Acc: 43.6877
# 		 Validation(10) - Loss: 1.9640, Acc: 31.3433
# 		 Training: Epoch(11) - Loss: 1.8452, Acc: 37.3754
# 		 Validation(11) - Loss: 1.8798, Acc: 35.8209
# 		 Training: Epoch(12) - Loss: 1.6709, Acc: 40.1993
# 		 Validation(12) - Loss: 1.6632, Acc: 40.2985
# 		 Training: Epoch(13) - Loss: 1.7266, Acc: 40.3654
# 		 Validation(13) - Loss: 1.4669, Acc: 49.2537
# 		 Training: Epoch(14) - Loss: 1.5682, Acc: 44.3522
# 		 Validation(14) - Loss: 1.5356, Acc: 49.2537
# Finished.
# Total time per fold: 322.55746150016785 seconds.
# Fold : 2
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.4958, Acc: 3.4884
# 		 Validation(0) - Loss: 3.4546, Acc: 2.9851
# 		 Training: Epoch(1) - Loss: 3.4497, Acc: 4.6512
# 		 Validation(1) - Loss: 3.3609, Acc: 2.9851
# 		 Training: Epoch(2) - Loss: 3.4494, Acc: 2.8239
# 		 Validation(2) - Loss: 3.4634, Acc: 2.9851
# 		 Training: Epoch(3) - Loss: 3.4239, Acc: 3.8206
# 		 Validation(3) - Loss: 3.3504, Acc: 4.4776
# 		 Training: Epoch(4) - Loss: 3.2461, Acc: 7.8073
# 		 Validation(4) - Loss: 3.2471, Acc: 7.4627
# 		 Training: Epoch(5) - Loss: 2.8939, Acc: 9.8007
# 		 Validation(5) - Loss: 2.7908, Acc: 17.9104
# 		 Training: Epoch(6) - Loss: 2.4058, Acc: 19.2691
# 		 Validation(6) - Loss: 2.5074, Acc: 16.4179
# 		 Training: Epoch(7) - Loss: 2.1255, Acc: 21.9269
# 		 Validation(7) - Loss: 1.8748, Acc: 28.3582
# 		 Training: Epoch(8) - Loss: 2.1267, Acc: 26.5781
# 		 Validation(8) - Loss: 2.0570, Acc: 31.3433
# 		 Training: Epoch(9) - Loss: 1.5411, Acc: 42.8571
# 		 Validation(9) - Loss: 1.7621, Acc: 38.8060
# 		 Training: Epoch(10) - Loss: 1.5899, Acc: 39.2027
# 		 Validation(10) - Loss: 1.1954, Acc: 52.2388
# 		 Training: Epoch(11) - Loss: 1.3311, Acc: 49.8339
# 		 Validation(11) - Loss: 1.3300, Acc: 50.7463
# 		 Training: Epoch(12) - Loss: 1.1400, Acc: 56.8106
# 		 Validation(12) - Loss: 1.6932, Acc: 46.2687
# 		 Training: Epoch(13) - Loss: 1.2822, Acc: 51.6611
# 		 Validation(13) - Loss: 1.1983, Acc: 49.2537
# 		 Training: Epoch(14) - Loss: 1.0521, Acc: 58.6379
# 		 Validation(14) - Loss: 0.9335, Acc: 59.7015
# Finished.
# Total time per fold: 321.80584931373596 seconds.
# Fold : 3
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.4145, Acc: 6.4784
# 		 Validation(0) - Loss: 3.3560, Acc: 14.9254
# 		 Training: Epoch(1) - Loss: 3.0930, Acc: 11.9601
# 		 Validation(1) - Loss: 3.3621, Acc: 10.4478
# 		 Training: Epoch(2) - Loss: 3.1509, Acc: 10.9635
# 		 Validation(2) - Loss: 3.0302, Acc: 10.4478
# 		 Training: Epoch(3) - Loss: 2.7690, Acc: 14.6179
# 		 Validation(3) - Loss: 2.5476, Acc: 11.9403
# 		 Training: Epoch(4) - Loss: 2.3045, Acc: 22.7575
# 		 Validation(4) - Loss: 1.9899, Acc: 26.8657
# 		 Training: Epoch(5) - Loss: 1.9358, Acc: 32.2259
# 		 Validation(5) - Loss: 2.3471, Acc: 13.4328
# 		 Training: Epoch(6) - Loss: 1.7537, Acc: 38.5382
# 		 Validation(6) - Loss: 2.2109, Acc: 32.8358
# 		 Training: Epoch(7) - Loss: 1.5725, Acc: 42.1927
# 		 Validation(7) - Loss: 1.4147, Acc: 52.2388
# 		 Training: Epoch(8) - Loss: 1.0261, Acc: 61.6279
# 		 Validation(8) - Loss: 1.0431, Acc: 61.1940
# 		 Training: Epoch(9) - Loss: 1.2138, Acc: 56.8106
# 		 Validation(9) - Loss: 2.0310, Acc: 34.3284
# 		 Training: Epoch(10) - Loss: 1.2989, Acc: 54.4850
# 		 Validation(10) - Loss: 1.2799, Acc: 49.2537
# 		 Training: Epoch(11) - Loss: 1.2211, Acc: 55.8140
# 		 Validation(11) - Loss: 0.9595, Acc: 61.1940
# 		 Training: Epoch(12) - Loss: 0.8984, Acc: 64.4518
# 		 Validation(12) - Loss: 1.1703, Acc: 61.1940
# 		 Training: Epoch(13) - Loss: 0.7636, Acc: 72.0930
# 		 Validation(13) - Loss: 1.1406, Acc: 62.6866
# 		 Training: Epoch(14) - Loss: 0.6193, Acc: 75.9136
# 		 Validation(14) - Loss: 0.7542, Acc: 77.6119
# Finished.
# Total time per fold: 321.75054574012756 seconds.
# Fold : 4
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.4230, Acc: 4.8173
# 		 Validation(0) - Loss: 3.2534, Acc: 5.9701
# 		 Training: Epoch(1) - Loss: 3.2164, Acc: 9.6346
# 		 Validation(1) - Loss: 2.9129, Acc: 13.4328
# 		 Training: Epoch(2) - Loss: 2.5217, Acc: 23.7542
# 		 Validation(2) - Loss: 2.4028, Acc: 26.8657
# 		 Training: Epoch(3) - Loss: 2.2291, Acc: 26.5781
# 		 Validation(3) - Loss: 1.9812, Acc: 31.3433
# 		 Training: Epoch(4) - Loss: 1.6016, Acc: 44.0199
# 		 Validation(4) - Loss: 1.5873, Acc: 46.2687
# 		 Training: Epoch(5) - Loss: 1.5346, Acc: 47.8405
# 		 Validation(5) - Loss: 1.8222, Acc: 34.3284
# 		 Training: Epoch(6) - Loss: 1.2359, Acc: 56.1462
# 		 Validation(6) - Loss: 1.6508, Acc: 43.2836
# 		 Training: Epoch(7) - Loss: 1.1311, Acc: 59.6346
# 		 Validation(7) - Loss: 0.8783, Acc: 74.6269
# 		 Training: Epoch(8) - Loss: 0.7583, Acc: 70.5980
# 		 Validation(8) - Loss: 1.0965, Acc: 59.7015
# 		 Training: Epoch(9) - Loss: 0.8899, Acc: 69.4352
# 		 Validation(9) - Loss: 0.8151, Acc: 73.1343
# 		 Training: Epoch(10) - Loss: 0.6352, Acc: 77.9070
# 		 Validation(10) - Loss: 0.7553, Acc: 68.6567
# 		 Training: Epoch(11) - Loss: 0.6376, Acc: 75.7475
# 		 Validation(11) - Loss: 0.6641, Acc: 73.1343
# 		 Training: Epoch(12) - Loss: 0.5828, Acc: 80.3987
# 		 Validation(12) - Loss: 0.9676, Acc: 73.1343
# 		 Training: Epoch(13) - Loss: 0.6594, Acc: 75.5814
# 		 Validation(13) - Loss: 0.6175, Acc: 73.1343
# 		 Training: Epoch(14) - Loss: 0.4594, Acc: 82.8904
# 		 Validation(14) - Loss: 1.2278, Acc: 62.6866
# Finished.
# Total time per fold: 320.00875878334045 seconds.
# Fold : 5
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.4767, Acc: 3.8206
# 		 Validation(0) - Loss: 3.3494, Acc: 7.4627
# 		 Training: Epoch(1) - Loss: 3.3854, Acc: 6.3123
# 		 Validation(1) - Loss: 3.2487, Acc: 10.4478
# 		 Training: Epoch(2) - Loss: 3.2623, Acc: 8.9701
# 		 Validation(2) - Loss: 2.9051, Acc: 23.8806
# 		 Training: Epoch(3) - Loss: 2.7735, Acc: 17.6080
# 		 Validation(3) - Loss: 2.7977, Acc: 20.8955
# 		 Training: Epoch(4) - Loss: 2.3804, Acc: 25.4153
# 		 Validation(4) - Loss: 1.9747, Acc: 29.8507
# 		 Training: Epoch(5) - Loss: 1.8685, Acc: 37.3754
# 		 Validation(5) - Loss: 1.4690, Acc: 46.2687
# 		 Training: Epoch(6) - Loss: 1.4979, Acc: 46.8439
# 		 Validation(6) - Loss: 1.5777, Acc: 44.7761
# 		 Training: Epoch(7) - Loss: 1.1540, Acc: 57.1429
# 		 Validation(7) - Loss: 1.2125, Acc: 55.2239
# 		 Training: Epoch(8) - Loss: 1.0370, Acc: 59.4684
# 		 Validation(8) - Loss: 1.2635, Acc: 55.2239
# 		 Training: Epoch(9) - Loss: 0.8388, Acc: 68.9369
# 		 Validation(9) - Loss: 1.4789, Acc: 61.1940
# 		 Training: Epoch(10) - Loss: 1.1793, Acc: 58.9701
# 		 Validation(10) - Loss: 1.3192, Acc: 50.7463
# 		 Training: Epoch(11) - Loss: 0.8255, Acc: 71.2625
# 		 Validation(11) - Loss: 0.9842, Acc: 62.6866
# 		 Training: Epoch(12) - Loss: 0.7307, Acc: 74.0864
# 		 Validation(12) - Loss: 1.0678, Acc: 70.1493
# 		 Training: Epoch(13) - Loss: 0.5803, Acc: 76.7442
# 		 Validation(13) - Loss: 1.6021, Acc: 53.7313
# 		 Training: Epoch(14) - Loss: 0.5989, Acc: 78.0731
# 		 Validation(14) - Loss: 0.7474, Acc: 76.1194
# Finished.
# Total time per fold: 317.91037034988403 seconds.
# Fold : 6
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.5378, Acc: 2.9900
# 		 Validation(0) - Loss: 3.6368, Acc: 1.4925
# 		 Training: Epoch(1) - Loss: 3.4700, Acc: 2.4917
# 		 Validation(1) - Loss: 3.4569, Acc: 7.4627
# 		 Training: Epoch(2) - Loss: 3.4543, Acc: 3.4884
# 		 Validation(2) - Loss: 3.3899, Acc: 10.4478
# 		 Training: Epoch(3) - Loss: 3.3875, Acc: 5.4817
# 		 Validation(3) - Loss: 2.8981, Acc: 13.4328
# 		 Training: Epoch(4) - Loss: 3.1228, Acc: 10.1329
# 		 Validation(4) - Loss: 2.7052, Acc: 16.4179
# 		 Training: Epoch(5) - Loss: 2.6236, Acc: 16.7774
# 		 Validation(5) - Loss: 2.5393, Acc: 19.4030
# 		 Training: Epoch(6) - Loss: 2.4042, Acc: 19.9336
# 		 Validation(6) - Loss: 3.1869, Acc: 13.4328
# 		 Training: Epoch(7) - Loss: 2.1510, Acc: 27.5748
# 		 Validation(7) - Loss: 2.1468, Acc: 28.3582
# 		 Training: Epoch(8) - Loss: 1.9829, Acc: 30.8970
# 		 Validation(8) - Loss: 1.8857, Acc: 22.3881
# 		 Training: Epoch(9) - Loss: 1.6991, Acc: 37.0432
# 		 Validation(9) - Loss: 1.4897, Acc: 46.2687
# 		 Training: Epoch(10) - Loss: 1.6371, Acc: 40.8638
# 		 Validation(10) - Loss: 1.4624, Acc: 46.2687
# 		 Training: Epoch(11) - Loss: 1.4865, Acc: 44.6844
# 		 Validation(11) - Loss: 1.2762, Acc: 52.2388
# 		 Training: Epoch(12) - Loss: 1.2882, Acc: 49.3355
# 		 Validation(12) - Loss: 1.2279, Acc: 49.2537
# 		 Training: Epoch(13) - Loss: 1.3269, Acc: 50.6645
# 		 Validation(13) - Loss: 1.5197, Acc: 46.2687
# 		 Training: Epoch(14) - Loss: 1.2898, Acc: 53.8206
# 		 Validation(14) - Loss: 1.1817, Acc: 56.7164
# Finished.
# Total time per fold: 323.6794846057892 seconds.
# Fold : 7
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.5076, Acc: 3.4884
# 		 Validation(0) - Loss: 3.4728, Acc: 1.4925
# 		 Training: Epoch(1) - Loss: 3.3802, Acc: 6.9767
# 		 Validation(1) - Loss: 3.4991, Acc: 1.4925
# 		 Training: Epoch(2) - Loss: 3.1437, Acc: 7.3090
# 		 Validation(2) - Loss: 3.3032, Acc: 2.9851
# 		 Training: Epoch(3) - Loss: 2.9788, Acc: 7.8073
# 		 Validation(3) - Loss: 2.9638, Acc: 11.9403
# 		 Training: Epoch(4) - Loss: 2.6796, Acc: 13.1229
# 		 Validation(4) - Loss: 2.8280, Acc: 1.4925
# 		 Training: Epoch(5) - Loss: 2.4127, Acc: 16.9435
# 		 Validation(5) - Loss: 2.5604, Acc: 17.9104
# 		 Training: Epoch(6) - Loss: 2.1874, Acc: 21.7608
# 		 Validation(6) - Loss: 2.6938, Acc: 14.9254
# 		 Training: Epoch(7) - Loss: 2.0578, Acc: 28.2392
# 		 Validation(7) - Loss: 2.2049, Acc: 16.4179
# 		 Training: Epoch(8) - Loss: 1.6543, Acc: 38.0399
# 		 Validation(8) - Loss: 1.8922, Acc: 35.8209
# 		 Training: Epoch(9) - Loss: 1.3704, Acc: 46.0133
# 		 Validation(9) - Loss: 1.9722, Acc: 46.2687
# 		 Training: Epoch(10) - Loss: 1.4921, Acc: 42.3588
# 		 Validation(10) - Loss: 2.1531, Acc: 35.8209
# 		 Training: Epoch(11) - Loss: 1.3166, Acc: 50.3322
# 		 Validation(11) - Loss: 1.3344, Acc: 55.2239
# 		 Training: Epoch(12) - Loss: 1.1170, Acc: 57.9734
# 		 Validation(12) - Loss: 1.6120, Acc: 46.2687
# 		 Training: Epoch(13) - Loss: 1.0631, Acc: 59.9668
# 		 Validation(13) - Loss: 1.0693, Acc: 55.2239
# 		 Training: Epoch(14) - Loss: 1.0044, Acc: 62.4585
# 		 Validation(14) - Loss: 0.9569, Acc: 58.2090
# Finished.
# Total time per fold: 321.60289311408997 seconds.
# Fold : 8
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.4032, Acc: 6.3123
# 		 Validation(0) - Loss: 3.2124, Acc: 11.9403
# 		 Training: Epoch(1) - Loss: 3.0766, Acc: 9.3023
# 		 Validation(1) - Loss: 3.1380, Acc: 7.4627
# 		 Training: Epoch(2) - Loss: 2.6072, Acc: 15.9468
# 		 Validation(2) - Loss: 2.5463, Acc: 22.3881
# 		 Training: Epoch(3) - Loss: 2.0837, Acc: 27.7409
# 		 Validation(3) - Loss: 1.9458, Acc: 32.8358
# 		 Training: Epoch(4) - Loss: 1.8592, Acc: 36.3787
# 		 Validation(4) - Loss: 1.7993, Acc: 29.8507
# 		 Training: Epoch(5) - Loss: 1.4758, Acc: 45.3488
# 		 Validation(5) - Loss: 1.8362, Acc: 44.7761
# 		 Training: Epoch(6) - Loss: 1.4817, Acc: 44.8505
# 		 Validation(6) - Loss: 1.3615, Acc: 50.7463
# 		 Training: Epoch(7) - Loss: 1.2077, Acc: 57.3090
# 		 Validation(7) - Loss: 1.0069, Acc: 53.7313
# 		 Training: Epoch(8) - Loss: 1.2143, Acc: 55.9801
# 		 Validation(8) - Loss: 1.1004, Acc: 64.1791
# 		 Training: Epoch(9) - Loss: 0.9740, Acc: 63.2890
# 		 Validation(9) - Loss: 1.4315, Acc: 59.7015
# 		 Training: Epoch(10) - Loss: 1.1475, Acc: 59.3023
# 		 Validation(10) - Loss: 1.2226, Acc: 61.1940
# 		 Training: Epoch(11) - Loss: 0.8521, Acc: 69.2691
# 		 Validation(11) - Loss: 0.8192, Acc: 74.6269
# 		 Training: Epoch(12) - Loss: 0.7167, Acc: 72.9236
# 		 Validation(12) - Loss: 0.7279, Acc: 79.1045
# 		 Training: Epoch(13) - Loss: 0.7498, Acc: 71.4286
# 		 Validation(13) - Loss: 1.1630, Acc: 61.1940
# 		 Training: Epoch(14) - Loss: 0.6660, Acc: 75.9136
# 		 Validation(14) - Loss: 1.0456, Acc: 73.1343
# Finished.
# Total time per fold: 320.1211564540863 seconds.
# Fold : 9
# Samples in training: 603
# Samples in test: 66
# 		 Training: Epoch(0) - Loss: 3.4984, Acc: 1.9900
# 		 Validation(0) - Loss: 3.4481, Acc: 3.0303
# 		 Training: Epoch(1) - Loss: 3.3317, Acc: 6.1360
# 		 Validation(1) - Loss: 3.2747, Acc: 4.5455
# 		 Training: Epoch(2) - Loss: 3.4434, Acc: 4.3118
# 		 Validation(2) - Loss: 3.4672, Acc: 1.5152
# 		 Training: Epoch(3) - Loss: 3.4383, Acc: 4.6434
# 		 Validation(3) - Loss: 3.4568, Acc: 3.0303
# 		 Training: Epoch(4) - Loss: 3.2909, Acc: 5.8043
# 		 Validation(4) - Loss: 3.3033, Acc: 3.0303
# 		 Training: Epoch(5) - Loss: 3.1419, Acc: 6.9652
# 		 Validation(5) - Loss: 3.2857, Acc: 3.0303
# 		 Training: Epoch(6) - Loss: 3.0094, Acc: 7.1310
# 		 Validation(6) - Loss: 3.0441, Acc: 6.0606
# 		 Training: Epoch(7) - Loss: 2.8192, Acc: 9.4527
# 		 Validation(7) - Loss: 2.7997, Acc: 9.0909
# 		 Training: Epoch(8) - Loss: 2.6842, Acc: 12.1061
# 		 Validation(8) - Loss: 2.8533, Acc: 7.5758
# 		 Training: Epoch(9) - Loss: 2.6248, Acc: 13.5987
# 		 Validation(9) - Loss: 2.6408, Acc: 16.6667
# 		 Training: Epoch(10) - Loss: 2.3979, Acc: 16.9154
# 		 Validation(10) - Loss: 2.1654, Acc: 25.7576
# 		 Training: Epoch(11) - Loss: 2.0823, Acc: 22.5539
# 		 Validation(11) - Loss: 1.8857, Acc: 31.8182
# 		 Training: Epoch(12) - Loss: 2.0669, Acc: 23.5489
# 		 Validation(12) - Loss: 2.1795, Acc: 15.1515
# 		 Training: Epoch(13) - Loss: 2.1159, Acc: 23.2172
# 		 Validation(13) - Loss: 2.1490, Acc: 24.2424
# 		 Training: Epoch(14) - Loss: 1.8421, Acc: 27.3632
# 		 Validation(14) - Loss: 1.6500, Acc: 31.8182
# Finished.
# Total time per fold: 320.48717427253723 seconds.

# %%
print("Train accuracy average: ", np.mean(train_acc) / 100)
print("Top-1 test accuracy average: ", np.mean(test_top1_acc))
print("Top-5 test accuracy average: ", np.mean(test_top5_acc))
print("Weighted Precision test accuracy average: ", np.mean(test_precision))
print("Weighted Recall test accuracy average: ", np.mean(test_recall))
print("Weighted F1 test accuracy average: ", np.mean(test_f1))
print("Average time per fold (seconds):", np.mean(times))
# Out:
# Train accuracy average:  0.32520645205129756
# Top-1 test accuracy average:  0.5810719131614653
# Top-5 test accuracy average:  0.9686114880144732
# Weighted Precision test accuracy average:  0.5675010768667483
# Weighted Recall test accuracy average:  0.5810719131614653
# Weighted F1 test accuracy average:  0.5403571650722261
# Average time per fold (seconds): 320.6574599027634
