# %% [markdown]
# # Code for the paper:
#
# ## Efficient and Mobile Deep Learning Architectures for Fast Identification of BacterialStrains in Resource-Constrained Devices
#
# ### Architecture: MobileNet v3 Small
# ### Data: Original + Cross-Validation

# %% [markdown]
# #### Loading libraries

# %%
# Imports here
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import torch.nn.functional as F
import pandas as pd
import time
import numpy as np

from PIL import Image
from sklearn.metrics import f1_score, precision_score, recall_score, classification_report
from sklearn.model_selection import KFold
from torch import nn
from torch import optim
from torch.utils.data import SubsetRandomSampler
from torchvision import datasets, transforms, models
from pytorch_model_summary import summary

# Archs not in Pytorch
from scripts.mobilenetv3 import mobilenetv3_small

# External functions
from scripts.utils import *

# %%
print(torch.__version__)

import sys
print(sys.version)
# Out:
# 1.5.1
# 3.8.5 (default, Jul 28 2020, 12:59:40)
# [GCC 9.3.0]

# %% [markdown]
# ## Data paths and hyperparameters

# %% [markdown]
# #### Hyperparameters and dataset details.

# %%
# Dataset details
dataset_version = 'original' # original or augmented
img_shape = (224,224)
img_size = str(img_shape[0])+"x"+str(img_shape[1])

# Root directory of dataset
data_dir = '/home/yibbtstll/venvs/pytorch_gpu/CySDeepBacterial/Dataset/DIBaS/'

train_batch_size = 32
val_test_batch_size = 32
feature_extract = False
pretrained = True
h_epochs = 10
kfolds = 10

# %% [markdown]
# ## Data preparation and loading

# %% [markdown]
# #### Defining transforms and creating dataloaders

# %%
# Define transforms for input data
training_transforms = transforms.Compose([transforms.Resize((224,224), Image.LANCZOS),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406], 
                                                               [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
total_set = datasets.ImageFolder(data_dir, transform=training_transforms)

# Defining folds
splits = KFold(n_splits = kfolds, shuffle = True, random_state = 42)

# %% [markdown]
# #### Visualizing the target classes in dataset

# %%
train_labels = {value : key for (key, value) in total_set.class_to_idx.items()}
    
print(len(train_labels)) 
print(train_labels)
# Out:
# 32
# {0: 'Acinetobacter.baumanii', 1: 'Actinomyces.israeli', 2: 'Bacteroides.fragilis', 3: 'Bifidobacterium.spp', 4: 'Clostridium.perfringens', 5: 'Enterococcus.faecalis', 6: 'Enterococcus.faecium', 7: 'Escherichia.coli', 8: 'Fusobacterium', 9: 'Lactobacillus.casei', 10: 'Lactobacillus.crispatus', 11: 'Lactobacillus.delbrueckii', 12: 'Lactobacillus.gasseri', 13: 'Lactobacillus.jehnsenii', 14: 'Lactobacillus.johnsonii', 15: 'Lactobacillus.paracasei', 16: 'Lactobacillus.plantarum', 17: 'Lactobacillus.reuteri', 18: 'Lactobacillus.rhamnosus', 19: 'Lactobacillus.salivarius', 20: 'Listeria.monocytogenes', 21: 'Micrococcus.spp', 22: 'Neisseria.gonorrhoeae', 23: 'Porfyromonas.gingivalis', 24: 'Propionibacterium.acnes', 25: 'Proteus', 26: 'Pseudomonas.aeruginosa', 27: 'Staphylococcus.aureus', 28: 'Staphylococcus.epidermidis', 29: 'Staphylococcus.saprophiticus', 30: 'Streptococcus.agalactiae', 31: 'Veionella'}

# %% [markdown]
# ## Model definition and inicialization

# %% [markdown]
# #### Freezing pre-trained parameters, finetunning the classifier to output 32 classes.

# %%
# Freeze pretrained model parameters to avoid backpropogating through them
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        print("Setting grad to false.")
        for param in model.parameters():
            param.requires_grad = False
    
    return model

def get_device():
    # Model and criterion to GPU
    if torch.cuda.is_available():
        return 'cuda'
    else:
        return 'cpu'

# %%
mobilenetv3_small()
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid(
#           (relu): ReLU6(inplace=True)
#         )
#       )
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): SELayer(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=16, out_features=8, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=8, out_features=16, bias=True)
#             (3): h_sigmoid(
#               (relu): ReLU6(inplace=True)
#             )
#           )
#         )
#         (4): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#         (4): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Identity()
#         (6): ReLU(inplace=True)
#         (7): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (4): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Identity()
#         (6): ReLU(inplace=True)
#         (7): Conv2d(88, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (3): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#         (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SELayer(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=96, out_features=24, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=24, out_features=96, bias=True)
#             (3): h_sigmoid(
#               (relu): ReLU6(inplace=True)
#             )
#           )
#         )
#         (6): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (7): Conv2d(96, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (3): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         (4): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SELayer(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=240, out_features=64, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=64, out_features=240, bias=True)
#             (3): h_sigmoid(
#               (relu): ReLU6(inplace=True)
#             )
#           )
#         )
#         (6): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (7): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (3): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         (4): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SELayer(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=240, out_features=64, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=64, out_features=240, bias=True)
#             (3): h_sigmoid(
#               (relu): ReLU6(inplace=True)
#             )
#           )
#         )
#         (6): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (7): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (3): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         (4): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SELayer(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=120, out_features=32, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=32, out_features=120, bias=True)
#             (3): h_sigmoid(
#               (relu): ReLU6(inplace=True)
#             )
#           )
#         )
#         (6): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (7): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(48, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (3): Conv2d(144, 144, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=144, bias=False)
#         (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SELayer(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=144, out_features=40, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=40, out_features=144, bias=True)
#             (3): h_sigmoid(
#               (relu): ReLU6(inplace=True)
#             )
#           )
#         )
#         (6): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (7): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (3): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#         (4): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SELayer(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=288, out_features=72, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=72, out_features=288, bias=True)
#             (3): h_sigmoid(
#               (relu): ReLU6(inplace=True)
#             )
#           )
#         )
#         (6): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (7): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (3): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#         (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SELayer(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=576, out_features=144, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=144, out_features=576, bias=True)
#             (3): h_sigmoid(
#               (relu): ReLU6(inplace=True)
#             )
#           )
#         )
#         (6): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (7): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (3): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#         (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): SELayer(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc): Sequential(
#             (0): Linear(in_features=576, out_features=144, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=144, out_features=576, bias=True)
#             (3): h_sigmoid(
#               (relu): ReLU6(inplace=True)
#             )
#           )
#         )
#         (6): h_swish(
#           (sigmoid): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (7): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv): Sequential(
#     (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid(
#         (relu): ReLU6(inplace=True)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (classifier): Sequential(
#     (0): Linear(in_features=576, out_features=1024, bias=True)
#     (1): h_swish(
#       (sigmoid): h_sigmoid(
#         (relu): ReLU6(inplace=True)
#       )
#     )
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1024, out_features=1000, bias=True)
#   )
# )

# %%
def load_model():
    # Transfer Learning
    model = mobilenetv3_small()
    model.load_state_dict(torch.load('scripts/pretrained/mobilenetv3-small-55df8e1f.pth'))
    
    # Mode
    model = set_parameter_requires_grad(model, feature_extract)
    
    # Fine tuning
    # Build custom classifier
    model.classifier[3] = nn.Linear(in_features=1024,
                                out_features=32)
    return model

def create_optimizer(model):
    # Parameters to update
    params_to_update = model.parameters()

    if feature_extract:
        params_to_update = []
        for param in model.parameters():
            if param.requires_grad == True:
                params_to_update.append(param)

    else:
        n_params = 0
        for param in model.parameters():
            if param.requires_grad == True:
                n_params += 1


    # Loss function and gradient descent

    criterion = nn.CrossEntropyLoss()

    optimizer = optim.Adam(params_to_update, 
                          lr=0.001, 
                          weight_decay=0.000004)
    
    return criterion.to(get_device()), model.to(get_device()), optimizer

# %% [markdown]
# ## Training, validation and test functions

# %%
# Variables to store fold scores
train_acc = []
test_top1_acc = []
test_top5_acc = []
test_precision = []
test_recall = []
test_f1 = []
times = []

for fold, (train_idx, valid_idx) in enumerate(splits.split(total_set)):
    
    start_time = time.time()
    
    print('Fold : {}'.format(fold))
    
    # Train and val samplers
    train_sampler = SubsetRandomSampler(train_idx)
    print("Samples in training:", len(train_sampler))
    valid_sampler = SubsetRandomSampler(valid_idx)
    print("Samples in test:", len(valid_sampler))
    
    # Train and val loaders
    train_loader = torch.utils.data.DataLoader(
                      total_set, batch_size=train_batch_size, sampler=train_sampler)
    valid_loader = torch.utils.data.DataLoader(
                      total_set, batch_size=1, sampler=valid_sampler)
    
    device = get_device()
    
    criterion, model, optimizer = create_optimizer(load_model())
    
    # Training
    for epoch in range(h_epochs):
        
        model.train()
        running_loss = 0.0
        running_corrects = 0
        trunning_corrects = 0
        
        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                
            running_loss += loss.item() * inputs.size(0)
            running_corrects += (preds == labels).sum()
            trunning_corrects += preds.size(0)
            

        epoch_loss = running_loss / trunning_corrects
        epoch_acc = (running_corrects.double()*100) / trunning_corrects
        train_acc.append(epoch_acc.item())
        
        print('\t\t Training: Epoch({}) - Loss: {:.4f}, Acc: {:.4f}'.format(epoch, epoch_loss, epoch_acc))
        
        # Validation
        
        model.eval()  
        
        vrunning_loss = 0.0
        vrunning_corrects = 0
        num_samples = 0
        
        for data, labels in valid_loader:
            
            data = data.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            
            with torch.no_grad():
                outputs = model(data)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                
            vrunning_loss += loss.item() * data.size(0)
            vrunning_corrects += (preds == labels).sum()
            num_samples += preds.size(0)
            
        vepoch_loss = vrunning_loss/num_samples
        vepoch_acc = (vrunning_corrects.double() * 100)/num_samples
        
        print('\t\t Validation({}) - Loss: {:.4f}, Acc: {:.4f}'.format(epoch, vepoch_loss, vepoch_acc))
    
    # Calculating and appending scores to this fold
    model.class_to_idx = total_set.class_to_idx
    scores = get_scores(model, valid_loader)
    
    test_top1_acc.append(scores[0])
    test_top5_acc.append(scores[1])
    test_precision.append(scores[2])
    test_recall.append(scores[3])
    test_f1.append(scores[4])
    
    time_fold = time.time() - start_time
    times.append(time_fold)
    print("Total time per fold: %s seconds." %(time_fold))
# Out:
# Fold : 0
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 1.6938, Acc: 54.3189
# 		 Validation(0) - Loss: 0.7276, Acc: 80.5970
# 		 Training: Epoch(1) - Loss: 0.3827, Acc: 85.8804
# 		 Validation(1) - Loss: 0.3681, Acc: 89.5522
# 		 Training: Epoch(2) - Loss: 0.2079, Acc: 93.3555
# 		 Validation(2) - Loss: 0.2710, Acc: 91.0448
# 		 Training: Epoch(3) - Loss: 0.1267, Acc: 95.5150
# 		 Validation(3) - Loss: 0.1386, Acc: 94.0299
# 		 Training: Epoch(4) - Loss: 0.1371, Acc: 95.5150
# 		 Validation(4) - Loss: 0.1308, Acc: 95.5224
# 		 Training: Epoch(5) - Loss: 0.1059, Acc: 96.6777
# 		 Validation(5) - Loss: 0.2137, Acc: 92.5373
# 		 Training: Epoch(6) - Loss: 0.1103, Acc: 97.1761
# 		 Validation(6) - Loss: 0.2252, Acc: 94.0299
# 		 Training: Epoch(7) - Loss: 0.0603, Acc: 97.6744
# 		 Validation(7) - Loss: 0.1622, Acc: 94.0299
# 		 Training: Epoch(8) - Loss: 0.0407, Acc: 98.8372
# 		 Validation(8) - Loss: 0.1291, Acc: 94.0299
# 		 Training: Epoch(9) - Loss: 0.0567, Acc: 98.5050
# 		 Validation(9) - Loss: 0.2610, Acc: 92.5373
# Finished.
# Total time per fold: 214.17800498008728 seconds.
# Fold : 1
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 1.7500, Acc: 51.1628
# 		 Validation(0) - Loss: 0.5297, Acc: 86.5672
# 		 Training: Epoch(1) - Loss: 0.3003, Acc: 89.5349
# 		 Validation(1) - Loss: 0.2910, Acc: 92.5373
# 		 Training: Epoch(2) - Loss: 0.1732, Acc: 94.6844
# 		 Validation(2) - Loss: 0.1795, Acc: 91.0448
# 		 Training: Epoch(3) - Loss: 0.0977, Acc: 96.5116
# 		 Validation(3) - Loss: 0.2766, Acc: 91.0448
# 		 Training: Epoch(4) - Loss: 0.1768, Acc: 95.8472
# 		 Validation(4) - Loss: 0.2948, Acc: 92.5373
# 		 Training: Epoch(5) - Loss: 0.2458, Acc: 94.5183
# 		 Validation(5) - Loss: 0.1831, Acc: 94.0299
# 		 Training: Epoch(6) - Loss: 0.1426, Acc: 96.1794
# 		 Validation(6) - Loss: 0.2596, Acc: 91.0448
# 		 Training: Epoch(7) - Loss: 0.1071, Acc: 97.8405
# 		 Validation(7) - Loss: 0.1481, Acc: 97.0149
# 		 Training: Epoch(8) - Loss: 0.1031, Acc: 97.3422
# 		 Validation(8) - Loss: 0.2692, Acc: 94.0299
# 		 Training: Epoch(9) - Loss: 0.0883, Acc: 97.3422
# 		 Validation(9) - Loss: 0.1722, Acc: 95.5224
# Finished.
# Total time per fold: 215.01488637924194 seconds.
# Fold : 2
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 1.6391, Acc: 55.4817
# 		 Validation(0) - Loss: 0.7551, Acc: 74.6269
# 		 Training: Epoch(1) - Loss: 0.3301, Acc: 89.7010
# 		 Validation(1) - Loss: 0.2809, Acc: 92.5373
# 		 Training: Epoch(2) - Loss: 0.2359, Acc: 93.6877
# 		 Validation(2) - Loss: 1.1494, Acc: 77.6119
# 		 Training: Epoch(3) - Loss: 0.2015, Acc: 93.3555
# 		 Validation(3) - Loss: 0.2644, Acc: 91.0448
# 		 Training: Epoch(4) - Loss: 0.0615, Acc: 98.3389
# 		 Validation(4) - Loss: 0.2341, Acc: 94.0299
# 		 Training: Epoch(5) - Loss: 0.0670, Acc: 98.3389
# 		 Validation(5) - Loss: 0.4626, Acc: 85.0746
# 		 Training: Epoch(6) - Loss: 0.0560, Acc: 98.6711
# 		 Validation(6) - Loss: 0.2313, Acc: 88.0597
# 		 Training: Epoch(7) - Loss: 0.0868, Acc: 98.3389
# 		 Validation(7) - Loss: 0.2458, Acc: 89.5522
# 		 Training: Epoch(8) - Loss: 0.0311, Acc: 99.1694
# 		 Validation(8) - Loss: 0.1585, Acc: 94.0299
# 		 Training: Epoch(9) - Loss: 0.0272, Acc: 99.5017
# 		 Validation(9) - Loss: 0.1201, Acc: 97.0149
# Finished.
# Total time per fold: 217.3120174407959 seconds.
# Fold : 3
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 1.6329, Acc: 56.1462
# 		 Validation(0) - Loss: 0.8130, Acc: 79.1045
# 		 Training: Epoch(1) - Loss: 0.4596, Acc: 85.0498
# 		 Validation(1) - Loss: 0.4912, Acc: 85.0746
# 		 Training: Epoch(2) - Loss: 0.1690, Acc: 95.1827
# 		 Validation(2) - Loss: 0.3404, Acc: 89.5522
# 		 Training: Epoch(3) - Loss: 0.1178, Acc: 96.8439
# 		 Validation(3) - Loss: 0.4152, Acc: 88.0597
# 		 Training: Epoch(4) - Loss: 0.0829, Acc: 98.1728
# 		 Validation(4) - Loss: 0.2827, Acc: 95.5224
# 		 Training: Epoch(5) - Loss: 0.0714, Acc: 97.3422
# 		 Validation(5) - Loss: 0.4242, Acc: 94.0299
# 		 Training: Epoch(6) - Loss: 0.0513, Acc: 98.5050
# 		 Validation(6) - Loss: 0.4538, Acc: 91.0448
# 		 Training: Epoch(7) - Loss: 0.0479, Acc: 98.6711
# 		 Validation(7) - Loss: 0.4996, Acc: 88.0597
# 		 Training: Epoch(8) - Loss: 0.1044, Acc: 96.8439
# 		 Validation(8) - Loss: 0.5246, Acc: 89.5522
# 		 Training: Epoch(9) - Loss: 0.1130, Acc: 97.8405
# 		 Validation(9) - Loss: 0.3484, Acc: 89.5522
# Finished.
# Total time per fold: 219.21220088005066 seconds.
# Fold : 4
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 1.6667, Acc: 55.8140
# 		 Validation(0) - Loss: 0.7086, Acc: 77.6119
# 		 Training: Epoch(1) - Loss: 0.3311, Acc: 90.1993
# 		 Validation(1) - Loss: 0.3580, Acc: 91.0448
# 		 Training: Epoch(2) - Loss: 0.1493, Acc: 94.6844
# 		 Validation(2) - Loss: 0.1607, Acc: 95.5224
# 		 Training: Epoch(3) - Loss: 0.1659, Acc: 94.6844
# 		 Validation(3) - Loss: 0.3280, Acc: 92.5373
# 		 Training: Epoch(4) - Loss: 0.0970, Acc: 97.5083
# 		 Validation(4) - Loss: 0.1550, Acc: 97.0149
# 		 Training: Epoch(5) - Loss: 0.0809, Acc: 98.5050
# 		 Validation(5) - Loss: 0.1461, Acc: 95.5224
# 		 Training: Epoch(6) - Loss: 0.0661, Acc: 98.1728
# 		 Validation(6) - Loss: 0.2983, Acc: 94.0299
# 		 Training: Epoch(7) - Loss: 0.0384, Acc: 98.8372
# 		 Validation(7) - Loss: 0.0479, Acc: 98.5075
# 		 Training: Epoch(8) - Loss: 0.0891, Acc: 96.6777
# 		 Validation(8) - Loss: 0.3127, Acc: 92.5373
# 		 Training: Epoch(9) - Loss: 0.0789, Acc: 97.8405
# 		 Validation(9) - Loss: 0.1910, Acc: 92.5373
# Finished.
# Total time per fold: 217.0373420715332 seconds.
# Fold : 5
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 1.7702, Acc: 54.3189
# 		 Validation(0) - Loss: 0.7323, Acc: 74.6269
# 		 Training: Epoch(1) - Loss: 0.3448, Acc: 88.8704
# 		 Validation(1) - Loss: 0.4005, Acc: 85.0746
# 		 Training: Epoch(2) - Loss: 0.1796, Acc: 94.6844
# 		 Validation(2) - Loss: 0.2714, Acc: 88.0597
# 		 Training: Epoch(3) - Loss: 0.1033, Acc: 96.1794
# 		 Validation(3) - Loss: 0.3408, Acc: 91.0448
# 		 Training: Epoch(4) - Loss: 0.1290, Acc: 95.6811
# 		 Validation(4) - Loss: 0.4171, Acc: 88.0597
# 		 Training: Epoch(5) - Loss: 0.0888, Acc: 96.8439
# 		 Validation(5) - Loss: 0.3821, Acc: 91.0448
# 		 Training: Epoch(6) - Loss: 0.1458, Acc: 95.8472
# 		 Validation(6) - Loss: 0.2916, Acc: 89.5522
# 		 Training: Epoch(7) - Loss: 0.0560, Acc: 98.8372
# 		 Validation(7) - Loss: 0.3262, Acc: 92.5373
# 		 Training: Epoch(8) - Loss: 0.0855, Acc: 97.3422
# 		 Validation(8) - Loss: 0.4722, Acc: 89.5522
# 		 Training: Epoch(9) - Loss: 0.0746, Acc: 98.0066
# 		 Validation(9) - Loss: 0.2804, Acc: 97.0149
# Finished.
# Total time per fold: 216.67201161384583 seconds.
# Fold : 6
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 1.6541, Acc: 57.1429
# 		 Validation(0) - Loss: 0.6370, Acc: 79.1045
# 		 Training: Epoch(1) - Loss: 0.3812, Acc: 85.5482
# 		 Validation(1) - Loss: 0.5275, Acc: 82.0896
# 		 Training: Epoch(2) - Loss: 0.3051, Acc: 92.1927
# 		 Validation(2) - Loss: 0.3468, Acc: 88.0597
# 		 Training: Epoch(3) - Loss: 0.1602, Acc: 94.5183
# 		 Validation(3) - Loss: 0.2890, Acc: 91.0448
# 		 Training: Epoch(4) - Loss: 0.0833, Acc: 97.3422
# 		 Validation(4) - Loss: 0.3874, Acc: 89.5522
# 		 Training: Epoch(5) - Loss: 0.0452, Acc: 98.3389
# 		 Validation(5) - Loss: 0.1496, Acc: 92.5373
# 		 Training: Epoch(6) - Loss: 0.0741, Acc: 97.3422
# 		 Validation(6) - Loss: 0.2297, Acc: 92.5373
# 		 Training: Epoch(7) - Loss: 0.0591, Acc: 98.1728
# 		 Validation(7) - Loss: 0.1840, Acc: 92.5373
# 		 Training: Epoch(8) - Loss: 0.2237, Acc: 93.6877
# 		 Validation(8) - Loss: 0.5380, Acc: 86.5672
# 		 Training: Epoch(9) - Loss: 0.1313, Acc: 96.8439
# 		 Validation(9) - Loss: 0.2741, Acc: 94.0299
# Finished.
# Total time per fold: 216.93771648406982 seconds.
# Fold : 7
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 1.6381, Acc: 53.9867
# 		 Validation(0) - Loss: 0.6470, Acc: 80.5970
# 		 Training: Epoch(1) - Loss: 0.2521, Acc: 91.0299
# 		 Validation(1) - Loss: 0.3784, Acc: 89.5522
# 		 Training: Epoch(2) - Loss: 0.1541, Acc: 94.1860
# 		 Validation(2) - Loss: 0.7057, Acc: 85.0746
# 		 Training: Epoch(3) - Loss: 0.1837, Acc: 95.1827
# 		 Validation(3) - Loss: 0.4343, Acc: 83.5821
# 		 Training: Epoch(4) - Loss: 0.1365, Acc: 95.8472
# 		 Validation(4) - Loss: 0.6368, Acc: 85.0746
# 		 Training: Epoch(5) - Loss: 0.1718, Acc: 95.0166
# 		 Validation(5) - Loss: 0.8509, Acc: 80.5970
# 		 Training: Epoch(6) - Loss: 0.1587, Acc: 95.1827
# 		 Validation(6) - Loss: 0.3088, Acc: 88.0597
# 		 Training: Epoch(7) - Loss: 0.1248, Acc: 96.3455
# 		 Validation(7) - Loss: 0.2059, Acc: 95.5224
# 		 Training: Epoch(8) - Loss: 0.0690, Acc: 98.0066
# 		 Validation(8) - Loss: 0.3817, Acc: 94.0299
# 		 Training: Epoch(9) - Loss: 0.0557, Acc: 98.1728
# 		 Validation(9) - Loss: 0.1577, Acc: 97.0149
# Finished.
# Total time per fold: 218.69034075737 seconds.
# Fold : 8
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 1.6419, Acc: 56.6445
# 		 Validation(0) - Loss: 0.6231, Acc: 80.5970
# 		 Training: Epoch(1) - Loss: 0.3846, Acc: 87.2093
# 		 Validation(1) - Loss: 0.3384, Acc: 85.0746
# 		 Training: Epoch(2) - Loss: 0.2117, Acc: 93.6877
# 		 Validation(2) - Loss: 0.2824, Acc: 92.5373
# 		 Training: Epoch(3) - Loss: 0.0767, Acc: 97.8405
# 		 Validation(3) - Loss: 0.3128, Acc: 91.0448
# 		 Training: Epoch(4) - Loss: 0.0980, Acc: 96.5116
# 		 Validation(4) - Loss: 0.5969, Acc: 88.0597
# 		 Training: Epoch(5) - Loss: 0.1079, Acc: 97.5083
# 		 Validation(5) - Loss: 0.2499, Acc: 94.0299
# 		 Training: Epoch(6) - Loss: 0.1524, Acc: 95.0166
# 		 Validation(6) - Loss: 0.4689, Acc: 85.0746
# 		 Training: Epoch(7) - Loss: 0.1705, Acc: 94.6844
# 		 Validation(7) - Loss: 0.3008, Acc: 88.0597
# 		 Training: Epoch(8) - Loss: 0.0724, Acc: 97.8405
# 		 Validation(8) - Loss: 0.1998, Acc: 92.5373
# 		 Training: Epoch(9) - Loss: 0.0482, Acc: 98.3389
# 		 Validation(9) - Loss: 0.3157, Acc: 91.0448
# Finished.
# Total time per fold: 217.63291120529175 seconds.
# Fold : 9
# Samples in training: 603
# Samples in test: 66
# 		 Training: Epoch(0) - Loss: 1.6295, Acc: 56.8823
# 		 Validation(0) - Loss: 0.6369, Acc: 78.7879
# 		 Training: Epoch(1) - Loss: 0.3452, Acc: 89.2206
# 		 Validation(1) - Loss: 0.6373, Acc: 84.8485
# 		 Training: Epoch(2) - Loss: 0.3161, Acc: 89.7181
# 		 Validation(2) - Loss: 0.5134, Acc: 81.8182
# 		 Training: Epoch(3) - Loss: 0.1550, Acc: 95.0249
# 		 Validation(3) - Loss: 0.3249, Acc: 92.4242
# 		 Training: Epoch(4) - Loss: 0.0971, Acc: 96.6833
# 		 Validation(4) - Loss: 0.2786, Acc: 90.9091
# 		 Training: Epoch(5) - Loss: 0.0836, Acc: 97.1808
# 		 Validation(5) - Loss: 0.4286, Acc: 90.9091
# 		 Training: Epoch(6) - Loss: 0.1390, Acc: 96.5174
# 		 Validation(6) - Loss: 0.4346, Acc: 86.3636
# 		 Training: Epoch(7) - Loss: 0.0537, Acc: 98.3416
# 		 Validation(7) - Loss: 0.4527, Acc: 86.3636
# 		 Training: Epoch(8) - Loss: 0.0695, Acc: 97.3466
# 		 Validation(8) - Loss: 0.5154, Acc: 92.4242
# 		 Training: Epoch(9) - Loss: 0.0752, Acc: 97.8441
# 		 Validation(9) - Loss: 0.5195, Acc: 87.8788
# Finished.
# Total time per fold: 216.31673121452332 seconds.

# %%
print("Train accuracy average: ", np.mean(train_acc) / 100)
print("Top-1 test accuracy average: ", np.mean(test_top1_acc))
print("Top-5 test accuracy average: ", np.mean(test_top5_acc))
print("Weighted Precision test accuracy average: ", np.mean(test_precision))
print("Weighted Recall test accuracy average: ", np.mean(test_recall))
print("Weighted F1 test accuracy average: ", np.mean(test_f1))
print("Average time per fold (seconds):", np.mean(times))
# Out:
# Train accuracy average:  0.9163264519043763
# Top-1 test accuracy average:  0.9341474445952057
# Top-5 test accuracy average:  0.9954997738579827
# Weighted Precision test accuracy average:  0.9548219939264715
# Weighted Recall test accuracy average:  0.9341474445952057
# Weighted F1 test accuracy average:  0.9341964274732254
# Average time per fold (seconds): 216.90041630268098
