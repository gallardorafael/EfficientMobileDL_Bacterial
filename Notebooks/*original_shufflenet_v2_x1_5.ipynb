# %% [markdown]
# # Code for the paper:
#
# ## Efficient and Mobile Deep Learning Architectures for Fast Identification of BacterialStrains in Resource-Constrained Devices
#
# ### Architecture: ShuffleNet v2x1.5
# ### Data: Original + Cross-Validation

# %% [markdown]
# #### Loading libraries

# %%
# Imports here
import os
import torch
import numpy as np
import torch.nn.functional as F
import pandas as pd
import time
import numpy as np

from PIL import Image
from sklearn.metrics import f1_score, precision_score, recall_score, classification_report
from sklearn.model_selection import KFold
from torch import nn
from torch import optim
from torch.utils.data import SubsetRandomSampler
from torchvision import datasets, transforms, models
from pytorch_model_summary import summary

# Archs not in Pytorch
from efficientnet_pytorch import EfficientNet

# External functions
from scripts.utils import *

# %%
print(torch.__version__)

import sys
print(sys.version)
# Out:
# 1.5.1
# 3.8.5 (default, Jul 28 2020, 12:59:40)
# [GCC 9.3.0]

# %% [markdown]
# ## Data paths and hyperparameters

# %% [markdown]
# #### Hyperparameters and dataset details.

# %%
# Dataset details
dataset_version = 'original' # original or augmented
img_shape = (224,224)
img_size = str(img_shape[0])+"x"+str(img_shape[1])

# Root directory of dataset
data_dir = '/home/yibbtstll/venvs/pytorch_gpu/CySDeepBacterial/Dataset/DIBaS/'

train_batch_size = 32
val_test_batch_size = 32
feature_extract = False
pretrained = False
h_epochs = 20
kfolds = 10

# %% [markdown]
# ## Data preparation and loading

# %% [markdown]
# #### Defining transforms and creating dataloaders

# %%
# Define transforms for input data
training_transforms = transforms.Compose([transforms.Resize((224,224), Image.LANCZOS),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406], 
                                                               [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
total_set = datasets.ImageFolder(data_dir, transform=training_transforms)

# Defining folds
splits = KFold(n_splits = kfolds, shuffle = True, random_state = 42)

# %% [markdown]
# #### Visualizing the target classes in dataset

# %%
train_labels = {value : key for (key, value) in total_set.class_to_idx.items()}
    
print(len(train_labels)) 
print(train_labels)
# Out:
# 32
# {0: 'Acinetobacter.baumanii', 1: 'Actinomyces.israeli', 2: 'Bacteroides.fragilis', 3: 'Bifidobacterium.spp', 4: 'Clostridium.perfringens', 5: 'Enterococcus.faecalis', 6: 'Enterococcus.faecium', 7: 'Escherichia.coli', 8: 'Fusobacterium', 9: 'Lactobacillus.casei', 10: 'Lactobacillus.crispatus', 11: 'Lactobacillus.delbrueckii', 12: 'Lactobacillus.gasseri', 13: 'Lactobacillus.jehnsenii', 14: 'Lactobacillus.johnsonii', 15: 'Lactobacillus.paracasei', 16: 'Lactobacillus.plantarum', 17: 'Lactobacillus.reuteri', 18: 'Lactobacillus.rhamnosus', 19: 'Lactobacillus.salivarius', 20: 'Listeria.monocytogenes', 21: 'Micrococcus.spp', 22: 'Neisseria.gonorrhoeae', 23: 'Porfyromonas.gingivalis', 24: 'Propionibacterium.acnes', 25: 'Proteus', 26: 'Pseudomonas.aeruginosa', 27: 'Staphylococcus.aureus', 28: 'Staphylococcus.epidermidis', 29: 'Staphylococcus.saprophiticus', 30: 'Streptococcus.agalactiae', 31: 'Veionella'}

# %% [markdown]
# ## Model definition and inicialization

# %% [markdown]
# #### Freezing pre-trained parameters, finetunning the classifier to output 32 classes.

# %%
# Freeze pretrained model parameters to avoid backpropogating through them
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        print("Setting grad to false.")
        for param in model.parameters():
            param.requires_grad = False
    
    return model

def get_device():
    # Model and criterion to GPU
    if torch.cuda.is_available():
        return 'cuda'
    else:
        return 'cpu'

# %%
models.shufflenet_v2_x1_5(pretrained=False)
# Out:
# ShuffleNetV2(
#   (conv1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (stage2): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(88, 88, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=88, bias=False)
#         (4): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (4): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (4): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#         (4): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(88, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (stage3): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(176, 176, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=176, bias=False)
#         (1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(176, 176, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=176, bias=False)
#         (4): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (4): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (4): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (4): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (4): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (4): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (5): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (4): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (6): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (4): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (7): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(176, 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=176, bias=False)
#         (4): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(176, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (stage4): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(352, 352, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=352, bias=False)
#         (1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(352, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(352, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(352, 352, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=352, bias=False)
#         (4): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(352, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(352, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(352, 352, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=352, bias=False)
#         (4): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(352, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(352, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(352, 352, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=352, bias=False)
#         (4): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(352, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(352, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(352, 352, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=352, bias=False)
#         (4): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(352, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (conv5): Sequential(
#     (0): Conv2d(704, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=1024, out_features=1000, bias=True)
# )

# %%
def load_model():
    # Transfer Learning
    model = models.shufflenet_v2_x1_5(pretrained=pretrained)
    
    # Mode
    model = set_parameter_requires_grad(model, feature_extract)
    
    # Fine tuning
    # Build custom classifier
    model.fc = nn.Linear(in_features=1024,
                        out_features=32)
    return model

def create_optimizer(model):
    # Parameters to update
    params_to_update = model.parameters()

    if feature_extract:
        params_to_update = []
        for param in model.parameters():
            if param.requires_grad == True:
                params_to_update.append(param)

    else:
        n_params = 0
        for param in model.parameters():
            if param.requires_grad == True:
                n_params += 1


    # Loss function and gradient descent

    criterion = nn.CrossEntropyLoss()

    optimizer = optim.Adam(params_to_update, 
                          lr=0.001, 
                          weight_decay=0.000004)
    
    return criterion.to(get_device()), model.to(get_device()), optimizer

# %% [markdown]
# ## Training, validation and test functions

# %%
# Variables to store fold scores
train_acc = []
test_top1_acc = []
test_top5_acc = []
test_precision = []
test_recall = []
test_f1 = []
times = []

for fold, (train_idx, valid_idx) in enumerate(splits.split(total_set)):
    
    start_time = time.time()
    
    print('Fold : {}'.format(fold))
    
    # Train and val samplers
    train_sampler = SubsetRandomSampler(train_idx)
    print("Samples in training:", len(train_sampler))
    valid_sampler = SubsetRandomSampler(valid_idx)
    print("Samples in test:", len(valid_sampler))
    
    # Train and val loaders
    train_loader = torch.utils.data.DataLoader(
                      total_set, batch_size=train_batch_size, sampler=train_sampler)
    valid_loader = torch.utils.data.DataLoader(
                      total_set, batch_size=1, sampler=valid_sampler)
    
    device = get_device()
    
    criterion, model, optimizer = create_optimizer(load_model())
    
    # Training
    for epoch in range(h_epochs):
        
        model.train()
        running_loss = 0.0
        running_corrects = 0
        trunning_corrects = 0
        
        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                
            running_loss += loss.item() * inputs.size(0)
            running_corrects += (preds == labels).sum()
            trunning_corrects += preds.size(0)
            

        epoch_loss = running_loss / trunning_corrects
        epoch_acc = (running_corrects.double()*100) / trunning_corrects
        train_acc.append(epoch_acc.item())
        
        print('\t\t Training: Epoch({}) - Loss: {:.4f}, Acc: {:.4f}'.format(epoch, epoch_loss, epoch_acc))
        
        # Validation
        
        model.eval()  
        
        vrunning_loss = 0.0
        vrunning_corrects = 0
        num_samples = 0
        
        for data, labels in valid_loader:
            
            data = data.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            
            with torch.no_grad():
                outputs = model(data)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                
            vrunning_loss += loss.item() * data.size(0)
            vrunning_corrects += (preds == labels).sum()
            num_samples += preds.size(0)
            
        vepoch_loss = vrunning_loss/num_samples
        vepoch_acc = (vrunning_corrects.double() * 100)/num_samples
        
        print('\t\t Validation({}) - Loss: {:.4f}, Acc: {:.4f}'.format(epoch, vepoch_loss, vepoch_acc))
    
    # Calculating and appending scores to this fold
    model.class_to_idx = total_set.class_to_idx
    scores = get_scores(model, valid_loader)
    
    test_top1_acc.append(scores[0])
    test_top5_acc.append(scores[1])
    test_precision.append(scores[2])
    test_recall.append(scores[3])
    test_f1.append(scores[4])
    
    time_fold = time.time() - start_time
    times.append(time_fold)
    print("Total time per fold: %s seconds." %(time_fold))
# Out:
# Fold : 0
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.1091, Acc: 10.1329
# 		 Validation(0) - Loss: 5.0955, Acc: 1.4925
# 		 Training: Epoch(1) - Loss: 2.0762, Acc: 30.5648
# 		 Validation(1) - Loss: 10.7331, Acc: 5.9701
# 		 Training: Epoch(2) - Loss: 1.5057, Acc: 44.1860
# 		 Validation(2) - Loss: 1.7471, Acc: 44.7761
# 		 Training: Epoch(3) - Loss: 1.2642, Acc: 53.8206
# 		 Validation(3) - Loss: 1.6974, Acc: 37.3134
# 		 Training: Epoch(4) - Loss: 0.9839, Acc: 65.4485
# 		 Validation(4) - Loss: 2.3195, Acc: 31.3433
# 		 Training: Epoch(5) - Loss: 0.9167, Acc: 66.6113
# 		 Validation(5) - Loss: 1.6047, Acc: 56.7164
# 		 Training: Epoch(6) - Loss: 0.6547, Acc: 76.7442
# 		 Validation(6) - Loss: 1.0565, Acc: 61.1940
# 		 Training: Epoch(7) - Loss: 0.6018, Acc: 79.9003
# 		 Validation(7) - Loss: 1.2162, Acc: 58.2090
# 		 Training: Epoch(8) - Loss: 0.6736, Acc: 75.7475
# 		 Validation(8) - Loss: 1.6378, Acc: 41.7910
# 		 Training: Epoch(9) - Loss: 0.7334, Acc: 74.9169
# 		 Validation(9) - Loss: 2.9451, Acc: 40.2985
# 		 Training: Epoch(10) - Loss: 0.6925, Acc: 74.2525
# 		 Validation(10) - Loss: 2.6216, Acc: 44.7761
# 		 Training: Epoch(11) - Loss: 0.4852, Acc: 81.2292
# 		 Validation(11) - Loss: 1.6586, Acc: 52.2388
# 		 Training: Epoch(12) - Loss: 0.4219, Acc: 85.7143
# 		 Validation(12) - Loss: 1.1669, Acc: 59.7015
# 		 Training: Epoch(13) - Loss: 0.3248, Acc: 89.8671
# 		 Validation(13) - Loss: 1.5655, Acc: 55.2239
# 		 Training: Epoch(14) - Loss: 0.2876, Acc: 91.3621
# 		 Validation(14) - Loss: 1.0112, Acc: 61.1940
# 		 Training: Epoch(15) - Loss: 0.3183, Acc: 90.0332
# 		 Validation(15) - Loss: 0.8922, Acc: 79.1045
# 		 Training: Epoch(16) - Loss: 0.2961, Acc: 91.1960
# 		 Validation(16) - Loss: 0.8954, Acc: 73.1343
# 		 Training: Epoch(17) - Loss: 0.2254, Acc: 93.6877
# 		 Validation(17) - Loss: 0.8869, Acc: 71.6418
# 		 Training: Epoch(18) - Loss: 0.1902, Acc: 95.0166
# 		 Validation(18) - Loss: 0.8964, Acc: 77.6119
# 		 Training: Epoch(19) - Loss: 0.1726, Acc: 94.1860
# 		 Validation(19) - Loss: 1.1456, Acc: 68.6567
# Finished.
# Total time per fold: 433.28692650794983 seconds.
# Fold : 1
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 2.9855, Acc: 13.1229
# 		 Validation(0) - Loss: 4.9714, Acc: 4.4776
# 		 Training: Epoch(1) - Loss: 2.0276, Acc: 31.2292
# 		 Validation(1) - Loss: 7.2715, Acc: 4.4776
# 		 Training: Epoch(2) - Loss: 1.7405, Acc: 37.5415
# 		 Validation(2) - Loss: 2.4181, Acc: 23.8806
# 		 Training: Epoch(3) - Loss: 1.4056, Acc: 46.6777
# 		 Validation(3) - Loss: 1.2931, Acc: 65.6716
# 		 Training: Epoch(4) - Loss: 1.1264, Acc: 60.2990
# 		 Validation(4) - Loss: 1.8237, Acc: 44.7761
# 		 Training: Epoch(5) - Loss: 1.1151, Acc: 59.6346
# 		 Validation(5) - Loss: 1.0833, Acc: 59.7015
# 		 Training: Epoch(6) - Loss: 1.0211, Acc: 63.7874
# 		 Validation(6) - Loss: 1.0989, Acc: 58.2090
# 		 Training: Epoch(7) - Loss: 0.8481, Acc: 70.0997
# 		 Validation(7) - Loss: 1.6499, Acc: 61.1940
# 		 Training: Epoch(8) - Loss: 0.7546, Acc: 75.5814
# 		 Validation(8) - Loss: 1.6727, Acc: 44.7761
# 		 Training: Epoch(9) - Loss: 0.6532, Acc: 76.5781
# 		 Validation(9) - Loss: 0.9258, Acc: 64.1791
# 		 Training: Epoch(10) - Loss: 0.5150, Acc: 82.3920
# 		 Validation(10) - Loss: 1.4369, Acc: 64.1791
# 		 Training: Epoch(11) - Loss: 0.5685, Acc: 80.8970
# 		 Validation(11) - Loss: 2.1809, Acc: 52.2388
# 		 Training: Epoch(12) - Loss: 0.5499, Acc: 82.5581
# 		 Validation(12) - Loss: 1.2851, Acc: 68.6567
# 		 Training: Epoch(13) - Loss: 0.4620, Acc: 86.3787
# 		 Validation(13) - Loss: 0.7106, Acc: 82.0896
# 		 Training: Epoch(14) - Loss: 0.3141, Acc: 89.5349
# 		 Validation(14) - Loss: 0.7224, Acc: 77.6119
# 		 Training: Epoch(15) - Loss: 0.3662, Acc: 88.8704
# 		 Validation(15) - Loss: 1.9570, Acc: 50.7463
# 		 Training: Epoch(16) - Loss: 0.3074, Acc: 88.0399
# 		 Validation(16) - Loss: 0.9759, Acc: 65.6716
# 		 Training: Epoch(17) - Loss: 0.3135, Acc: 91.0299
# 		 Validation(17) - Loss: 1.0725, Acc: 62.6866
# 		 Training: Epoch(18) - Loss: 0.2774, Acc: 90.1993
# 		 Validation(18) - Loss: 0.8852, Acc: 68.6567
# 		 Training: Epoch(19) - Loss: 0.1757, Acc: 94.8505
# 		 Validation(19) - Loss: 1.0541, Acc: 73.1343
# Finished.
# Total time per fold: 443.0150218009949 seconds.
# Fold : 2
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.0336, Acc: 12.1262
# 		 Validation(0) - Loss: 5.2862, Acc: 2.9851
# 		 Training: Epoch(1) - Loss: 2.0086, Acc: 33.7209
# 		 Validation(1) - Loss: 7.2731, Acc: 2.9851
# 		 Training: Epoch(2) - Loss: 1.6312, Acc: 41.5282
# 		 Validation(2) - Loss: 1.8039, Acc: 47.7612
# 		 Training: Epoch(3) - Loss: 1.2474, Acc: 54.4850
# 		 Validation(3) - Loss: 1.5120, Acc: 47.7612
# 		 Training: Epoch(4) - Loss: 1.0266, Acc: 64.9502
# 		 Validation(4) - Loss: 1.9012, Acc: 35.8209
# 		 Training: Epoch(5) - Loss: 1.1402, Acc: 57.4751
# 		 Validation(5) - Loss: 1.5222, Acc: 55.2239
# 		 Training: Epoch(6) - Loss: 0.8170, Acc: 72.2591
# 		 Validation(6) - Loss: 1.9820, Acc: 38.8060
# 		 Training: Epoch(7) - Loss: 0.6671, Acc: 76.4120
# 		 Validation(7) - Loss: 1.4292, Acc: 49.2537
# 		 Training: Epoch(8) - Loss: 0.6940, Acc: 76.7442
# 		 Validation(8) - Loss: 1.4371, Acc: 62.6866
# 		 Training: Epoch(9) - Loss: 0.4984, Acc: 84.0532
# 		 Validation(9) - Loss: 2.0827, Acc: 46.2687
# 		 Training: Epoch(10) - Loss: 0.3999, Acc: 86.3787
# 		 Validation(10) - Loss: 1.3743, Acc: 59.7015
# 		 Training: Epoch(11) - Loss: 0.4030, Acc: 87.2093
# 		 Validation(11) - Loss: 1.6464, Acc: 62.6866
# 		 Training: Epoch(12) - Loss: 0.4347, Acc: 86.7110
# 		 Validation(12) - Loss: 1.5443, Acc: 52.2388
# 		 Training: Epoch(13) - Loss: 0.3686, Acc: 88.2060
# 		 Validation(13) - Loss: 1.4758, Acc: 64.1791
# 		 Training: Epoch(14) - Loss: 0.3258, Acc: 88.0399
# 		 Validation(14) - Loss: 2.0164, Acc: 52.2388
# 		 Training: Epoch(15) - Loss: 0.3036, Acc: 89.7010
# 		 Validation(15) - Loss: 1.9767, Acc: 46.2687
# 		 Training: Epoch(16) - Loss: 0.3570, Acc: 88.8704
# 		 Validation(16) - Loss: 2.0678, Acc: 49.2537
# 		 Training: Epoch(17) - Loss: 0.2806, Acc: 91.0299
# 		 Validation(17) - Loss: 1.3726, Acc: 59.7015
# 		 Training: Epoch(18) - Loss: 0.2406, Acc: 92.5249
# 		 Validation(18) - Loss: 1.3111, Acc: 67.1642
# 		 Training: Epoch(19) - Loss: 0.1829, Acc: 95.0166
# 		 Validation(19) - Loss: 1.7286, Acc: 61.1940
# Finished.
# Total time per fold: 444.1417202949524 seconds.
# Fold : 3
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.0056, Acc: 12.1262
# 		 Validation(0) - Loss: 4.8520, Acc: 1.4925
# 		 Training: Epoch(1) - Loss: 2.0184, Acc: 28.4053
# 		 Validation(1) - Loss: 5.3722, Acc: 13.4328
# 		 Training: Epoch(2) - Loss: 1.7766, Acc: 36.3787
# 		 Validation(2) - Loss: 1.9395, Acc: 34.3284
# 		 Training: Epoch(3) - Loss: 1.4218, Acc: 45.8472
# 		 Validation(3) - Loss: 1.7831, Acc: 37.3134
# 		 Training: Epoch(4) - Loss: 1.1880, Acc: 52.4917
# 		 Validation(4) - Loss: 1.6899, Acc: 35.8209
# 		 Training: Epoch(5) - Loss: 1.0788, Acc: 59.9668
# 		 Validation(5) - Loss: 1.1997, Acc: 52.2388
# 		 Training: Epoch(6) - Loss: 0.9548, Acc: 62.1262
# 		 Validation(6) - Loss: 1.3028, Acc: 59.7015
# 		 Training: Epoch(7) - Loss: 0.8134, Acc: 70.2658
# 		 Validation(7) - Loss: 1.5110, Acc: 61.1940
# 		 Training: Epoch(8) - Loss: 0.7430, Acc: 71.9269
# 		 Validation(8) - Loss: 1.8638, Acc: 49.2537
# 		 Training: Epoch(9) - Loss: 0.6924, Acc: 77.4086
# 		 Validation(9) - Loss: 1.2624, Acc: 62.6866
# 		 Training: Epoch(10) - Loss: 0.5567, Acc: 80.2326
# 		 Validation(10) - Loss: 1.8924, Acc: 55.2239
# 		 Training: Epoch(11) - Loss: 0.6147, Acc: 79.2359
# 		 Validation(11) - Loss: 1.1148, Acc: 68.6567
# 		 Training: Epoch(12) - Loss: 0.5262, Acc: 82.5581
# 		 Validation(12) - Loss: 1.3760, Acc: 62.6866
# 		 Training: Epoch(13) - Loss: 0.3993, Acc: 87.5415
# 		 Validation(13) - Loss: 1.3050, Acc: 64.1791
# 		 Training: Epoch(14) - Loss: 0.3678, Acc: 88.2060
# 		 Validation(14) - Loss: 1.0619, Acc: 71.6418
# 		 Training: Epoch(15) - Loss: 0.3252, Acc: 88.5382
# 		 Validation(15) - Loss: 0.8656, Acc: 76.1194
# 		 Training: Epoch(16) - Loss: 0.2648, Acc: 91.6944
# 		 Validation(16) - Loss: 0.9808, Acc: 74.6269
# 		 Training: Epoch(17) - Loss: 0.2752, Acc: 92.6910
# 		 Validation(17) - Loss: 1.1293, Acc: 67.1642
# 		 Training: Epoch(18) - Loss: 0.3067, Acc: 89.3688
# 		 Validation(18) - Loss: 0.8630, Acc: 73.1343
# 		 Training: Epoch(19) - Loss: 0.2245, Acc: 93.0233
# 		 Validation(19) - Loss: 1.1619, Acc: 65.6716
# Finished.
# Total time per fold: 453.25137734413147 seconds.
# Fold : 4
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 2.9904, Acc: 11.9601
# 		 Validation(0) - Loss: 4.9890, Acc: 2.9851
# 		 Training: Epoch(1) - Loss: 2.1484, Acc: 26.9103
# 		 Validation(1) - Loss: 6.0104, Acc: 10.4478
# 		 Training: Epoch(2) - Loss: 1.7711, Acc: 35.0498
# 		 Validation(2) - Loss: 1.5772, Acc: 44.7761
# 		 Training: Epoch(3) - Loss: 1.4932, Acc: 42.8571
# 		 Validation(3) - Loss: 1.6022, Acc: 44.7761
# 		 Training: Epoch(4) - Loss: 1.2996, Acc: 51.9934
# 		 Validation(4) - Loss: 1.4617, Acc: 49.2537
# 		 Training: Epoch(5) - Loss: 1.3091, Acc: 52.8239
# 		 Validation(5) - Loss: 1.3317, Acc: 53.7313
# 		 Training: Epoch(6) - Loss: 1.1015, Acc: 59.3023
# 		 Validation(6) - Loss: 2.0561, Acc: 32.8358
# 		 Training: Epoch(7) - Loss: 0.8775, Acc: 69.4352
# 		 Validation(7) - Loss: 1.9027, Acc: 41.7910
# 		 Training: Epoch(8) - Loss: 0.7553, Acc: 72.9236
# 		 Validation(8) - Loss: 0.9612, Acc: 59.7015
# 		 Training: Epoch(9) - Loss: 0.6590, Acc: 77.5748
# 		 Validation(9) - Loss: 0.8927, Acc: 59.7015
# 		 Training: Epoch(10) - Loss: 0.5763, Acc: 81.8937
# 		 Validation(10) - Loss: 1.4016, Acc: 52.2388
# 		 Training: Epoch(11) - Loss: 0.7858, Acc: 73.2558
# 		 Validation(11) - Loss: 2.0708, Acc: 50.7463
# 		 Training: Epoch(12) - Loss: 0.6963, Acc: 77.0764
# 		 Validation(12) - Loss: 1.3019, Acc: 55.2239
# 		 Training: Epoch(13) - Loss: 0.3699, Acc: 88.5382
# 		 Validation(13) - Loss: 0.6961, Acc: 77.6119
# 		 Training: Epoch(14) - Loss: 0.3070, Acc: 90.5316
# 		 Validation(14) - Loss: 1.4167, Acc: 55.2239
# 		 Training: Epoch(15) - Loss: 0.3410, Acc: 89.8671
# 		 Validation(15) - Loss: 1.7084, Acc: 56.7164
# 		 Training: Epoch(16) - Loss: 0.3314, Acc: 88.8704
# 		 Validation(16) - Loss: 1.0207, Acc: 74.6269
# 		 Training: Epoch(17) - Loss: 0.2426, Acc: 92.3588
# 		 Validation(17) - Loss: 1.4456, Acc: 56.7164
# 		 Training: Epoch(18) - Loss: 0.2808, Acc: 92.8571
# 		 Validation(18) - Loss: 1.6694, Acc: 61.1940
# 		 Training: Epoch(19) - Loss: 0.2366, Acc: 91.1960
# 		 Validation(19) - Loss: 2.2951, Acc: 49.2537
# Finished.
# Total time per fold: 442.88026332855225 seconds.
# Fold : 5
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.0819, Acc: 9.9668
# 		 Validation(0) - Loss: 5.0641, Acc: 5.9701
# 		 Training: Epoch(1) - Loss: 2.0339, Acc: 32.8904
# 		 Validation(1) - Loss: 6.8416, Acc: 2.9851
# 		 Training: Epoch(2) - Loss: 1.4791, Acc: 46.8439
# 		 Validation(2) - Loss: 2.1231, Acc: 26.8657
# 		 Training: Epoch(3) - Loss: 1.2174, Acc: 57.3090
# 		 Validation(3) - Loss: 1.3679, Acc: 46.2687
# 		 Training: Epoch(4) - Loss: 0.9427, Acc: 66.6113
# 		 Validation(4) - Loss: 1.3877, Acc: 50.7463
# 		 Training: Epoch(5) - Loss: 0.8597, Acc: 70.0997
# 		 Validation(5) - Loss: 1.5131, Acc: 52.2388
# 		 Training: Epoch(6) - Loss: 0.9413, Acc: 66.2791
# 		 Validation(6) - Loss: 1.6355, Acc: 53.7313
# 		 Training: Epoch(7) - Loss: 0.8926, Acc: 68.1063
# 		 Validation(7) - Loss: 1.7894, Acc: 46.2687
# 		 Training: Epoch(8) - Loss: 0.7347, Acc: 74.5847
# 		 Validation(8) - Loss: 1.5738, Acc: 49.2537
# 		 Training: Epoch(9) - Loss: 0.5417, Acc: 81.5615
# 		 Validation(9) - Loss: 1.8683, Acc: 46.2687
# 		 Training: Epoch(10) - Loss: 0.5320, Acc: 82.2259
# 		 Validation(10) - Loss: 1.5918, Acc: 49.2537
# 		 Training: Epoch(11) - Loss: 0.4225, Acc: 85.5482
# 		 Validation(11) - Loss: 1.4853, Acc: 62.6866
# 		 Training: Epoch(12) - Loss: 0.5145, Acc: 82.0598
# 		 Validation(12) - Loss: 1.8463, Acc: 49.2537
# 		 Training: Epoch(13) - Loss: 0.3644, Acc: 88.0399
# 		 Validation(13) - Loss: 1.4634, Acc: 58.2090
# 		 Training: Epoch(14) - Loss: 0.3500, Acc: 87.7076
# 		 Validation(14) - Loss: 0.7849, Acc: 73.1343
# 		 Training: Epoch(15) - Loss: 0.3326, Acc: 89.3688
# 		 Validation(15) - Loss: 0.9908, Acc: 64.1791
# 		 Training: Epoch(16) - Loss: 0.2946, Acc: 91.6944
# 		 Validation(16) - Loss: 1.4498, Acc: 61.1940
# 		 Training: Epoch(17) - Loss: 0.2910, Acc: 89.7010
# 		 Validation(17) - Loss: 1.0421, Acc: 70.1493
# 		 Training: Epoch(18) - Loss: 0.2444, Acc: 92.3588
# 		 Validation(18) - Loss: 1.1173, Acc: 67.1642
# 		 Training: Epoch(19) - Loss: 0.2387, Acc: 92.8571
# 		 Validation(19) - Loss: 1.1906, Acc: 70.1493
# Finished.
# Total time per fold: 447.28394770622253 seconds.
# Fold : 6
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 3.1010, Acc: 10.7973
# 		 Validation(0) - Loss: 6.2604, Acc: 2.9851
# 		 Training: Epoch(1) - Loss: 2.1198, Acc: 30.0664
# 		 Validation(1) - Loss: 8.5551, Acc: 4.4776
# 		 Training: Epoch(2) - Loss: 1.7250, Acc: 38.5382
# 		 Validation(2) - Loss: 2.3632, Acc: 31.3433
# 		 Training: Epoch(3) - Loss: 1.4009, Acc: 50.6645
# 		 Validation(3) - Loss: 1.3776, Acc: 53.7313
# 		 Training: Epoch(4) - Loss: 1.0862, Acc: 59.6346
# 		 Validation(4) - Loss: 2.4523, Acc: 40.2985
# 		 Training: Epoch(5) - Loss: 0.9455, Acc: 65.2824
# 		 Validation(5) - Loss: 0.9417, Acc: 64.1791
# 		 Training: Epoch(6) - Loss: 0.7590, Acc: 74.2525
# 		 Validation(6) - Loss: 1.3299, Acc: 46.2687
# 		 Training: Epoch(7) - Loss: 0.6916, Acc: 76.0797
# 		 Validation(7) - Loss: 0.9121, Acc: 68.6567
# 		 Training: Epoch(8) - Loss: 0.6732, Acc: 77.5748
# 		 Validation(8) - Loss: 1.6511, Acc: 56.7164
# 		 Training: Epoch(9) - Loss: 0.5785, Acc: 81.3953
# 		 Validation(9) - Loss: 1.0516, Acc: 68.6567
# 		 Training: Epoch(10) - Loss: 0.5466, Acc: 81.8937
# 		 Validation(10) - Loss: 1.1032, Acc: 62.6866
# 		 Training: Epoch(11) - Loss: 0.4765, Acc: 85.2159
# 		 Validation(11) - Loss: 0.9984, Acc: 71.6418
# 		 Training: Epoch(12) - Loss: 0.3288, Acc: 90.0332
# 		 Validation(12) - Loss: 0.6074, Acc: 74.6269
# 		 Training: Epoch(13) - Loss: 0.2189, Acc: 94.8505
# 		 Validation(13) - Loss: 0.7794, Acc: 77.6119
# 		 Training: Epoch(14) - Loss: 0.2534, Acc: 93.3555
# 		 Validation(14) - Loss: 0.6397, Acc: 77.6119
# 		 Training: Epoch(15) - Loss: 0.2830, Acc: 91.8605
# 		 Validation(15) - Loss: 0.8465, Acc: 73.1343
# 		 Training: Epoch(16) - Loss: 0.3454, Acc: 89.2027
# 		 Validation(16) - Loss: 1.2578, Acc: 67.1642
# 		 Training: Epoch(17) - Loss: 0.2819, Acc: 89.7010
# 		 Validation(17) - Loss: 2.1091, Acc: 53.7313
# 		 Training: Epoch(18) - Loss: 0.2300, Acc: 92.5249
# 		 Validation(18) - Loss: 1.9864, Acc: 53.7313
# 		 Training: Epoch(19) - Loss: 0.2306, Acc: 92.6910
# 		 Validation(19) - Loss: 1.2990, Acc: 64.1791
# Finished.
# Total time per fold: 445.9213366508484 seconds.
# Fold : 7
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 2.9625, Acc: 15.2824
# 		 Validation(0) - Loss: 4.6958, Acc: 1.4925
# 		 Training: Epoch(1) - Loss: 1.9802, Acc: 28.2392
# 		 Validation(1) - Loss: 5.6261, Acc: 7.4627
# 		 Training: Epoch(2) - Loss: 1.4105, Acc: 49.1694
# 		 Validation(2) - Loss: 1.7495, Acc: 29.8507
# 		 Training: Epoch(3) - Loss: 1.2966, Acc: 50.0000
# 		 Validation(3) - Loss: 1.8327, Acc: 38.8060
# 		 Training: Epoch(4) - Loss: 1.1052, Acc: 60.9635
# 		 Validation(4) - Loss: 2.5423, Acc: 29.8507
# 		 Training: Epoch(5) - Loss: 0.9103, Acc: 69.6013
# 		 Validation(5) - Loss: 1.7985, Acc: 41.7910
# 		 Training: Epoch(6) - Loss: 0.7765, Acc: 72.5914
# 		 Validation(6) - Loss: 1.9731, Acc: 43.2836
# 		 Training: Epoch(7) - Loss: 0.6825, Acc: 77.0764
# 		 Validation(7) - Loss: 1.8799, Acc: 49.2537
# 		 Training: Epoch(8) - Loss: 0.5312, Acc: 82.8904
# 		 Validation(8) - Loss: 1.4640, Acc: 59.7015
# 		 Training: Epoch(9) - Loss: 0.5423, Acc: 81.0631
# 		 Validation(9) - Loss: 2.0244, Acc: 47.7612
# 		 Training: Epoch(10) - Loss: 0.5056, Acc: 83.0565
# 		 Validation(10) - Loss: 1.9762, Acc: 49.2537
# 		 Training: Epoch(11) - Loss: 0.4657, Acc: 83.8870
# 		 Validation(11) - Loss: 1.5972, Acc: 58.2090
# 		 Training: Epoch(12) - Loss: 0.5124, Acc: 82.8904
# 		 Validation(12) - Loss: 1.3784, Acc: 59.7015
# 		 Training: Epoch(13) - Loss: 0.4775, Acc: 83.3887
# 		 Validation(13) - Loss: 1.5228, Acc: 53.7313
# 		 Training: Epoch(14) - Loss: 0.3844, Acc: 87.7076
# 		 Validation(14) - Loss: 1.8806, Acc: 52.2388
# 		 Training: Epoch(15) - Loss: 0.3379, Acc: 89.5349
# 		 Validation(15) - Loss: 1.5912, Acc: 58.2090
# 		 Training: Epoch(16) - Loss: 0.3115, Acc: 89.2027
# 		 Validation(16) - Loss: 1.3085, Acc: 59.7015
# 		 Training: Epoch(17) - Loss: 0.2750, Acc: 91.1960
# 		 Validation(17) - Loss: 1.1151, Acc: 61.1940
# 		 Training: Epoch(18) - Loss: 0.1535, Acc: 96.1794
# 		 Validation(18) - Loss: 1.0255, Acc: 65.6716
# 		 Training: Epoch(19) - Loss: 0.1896, Acc: 94.8505
# 		 Validation(19) - Loss: 1.2837, Acc: 64.1791
# Finished.
# Total time per fold: 450.07160091400146 seconds.
# Fold : 8
# Samples in training: 602
# Samples in test: 67
# 		 Training: Epoch(0) - Loss: 2.9965, Acc: 15.1163
# 		 Validation(0) - Loss: 4.4938, Acc: 4.4776
# 		 Training: Epoch(1) - Loss: 1.9032, Acc: 29.7342
# 		 Validation(1) - Loss: 5.1694, Acc: 5.9701
# 		 Training: Epoch(2) - Loss: 1.5857, Acc: 45.1827
# 		 Validation(2) - Loss: 2.1892, Acc: 32.8358
# 		 Training: Epoch(3) - Loss: 1.3022, Acc: 51.1628
# 		 Validation(3) - Loss: 1.6180, Acc: 35.8209
# 		 Training: Epoch(4) - Loss: 1.1000, Acc: 62.2924
# 		 Validation(4) - Loss: 1.3428, Acc: 55.2239
# 		 Training: Epoch(5) - Loss: 0.9186, Acc: 67.7741
# 		 Validation(5) - Loss: 1.0544, Acc: 61.1940
# 		 Training: Epoch(6) - Loss: 0.7690, Acc: 70.7641
# 		 Validation(6) - Loss: 1.2418, Acc: 56.7164
# 		 Training: Epoch(7) - Loss: 0.6551, Acc: 77.9070
# 		 Validation(7) - Loss: 2.0393, Acc: 43.2836
# 		 Training: Epoch(8) - Loss: 0.7816, Acc: 73.2558
# 		 Validation(8) - Loss: 1.9639, Acc: 43.2836
# 		 Training: Epoch(9) - Loss: 0.6814, Acc: 74.2525
# 		 Validation(9) - Loss: 2.1585, Acc: 41.7910
# 		 Training: Epoch(10) - Loss: 0.5046, Acc: 83.8870
# 		 Validation(10) - Loss: 1.0269, Acc: 67.1642
# 		 Training: Epoch(11) - Loss: 0.5257, Acc: 84.2193
# 		 Validation(11) - Loss: 1.1707, Acc: 52.2388
# 		 Training: Epoch(12) - Loss: 0.4430, Acc: 84.8837
# 		 Validation(12) - Loss: 1.3301, Acc: 65.6716
# 		 Training: Epoch(13) - Loss: 0.3802, Acc: 86.7110
# 		 Validation(13) - Loss: 1.2473, Acc: 59.7015
# 		 Training: Epoch(14) - Loss: 0.4475, Acc: 86.0465
# 		 Validation(14) - Loss: 1.5389, Acc: 62.6866
# 		 Training: Epoch(15) - Loss: 0.3352, Acc: 90.0332
# 		 Validation(15) - Loss: 0.8903, Acc: 68.6567
# 		 Training: Epoch(16) - Loss: 0.3032, Acc: 90.6977
# 		 Validation(16) - Loss: 0.8578, Acc: 70.1493
# 		 Training: Epoch(17) - Loss: 0.2271, Acc: 93.6877
# 		 Validation(17) - Loss: 1.0991, Acc: 65.6716
# 		 Training: Epoch(18) - Loss: 0.1880, Acc: 95.6811
# 		 Validation(18) - Loss: 1.3048, Acc: 70.1493
# 		 Training: Epoch(19) - Loss: 0.2676, Acc: 91.6944
# 		 Validation(19) - Loss: 1.9225, Acc: 53.7313
# Finished.
# Total time per fold: 443.39421558380127 seconds.
# Fold : 9
# Samples in training: 603
# Samples in test: 66
# 		 Training: Epoch(0) - Loss: 3.0852, Acc: 11.1111
# 		 Validation(0) - Loss: 4.6533, Acc: 1.5152
# 		 Training: Epoch(1) - Loss: 2.0985, Acc: 29.6849
# 		 Validation(1) - Loss: 7.1863, Acc: 6.0606
# 		 Training: Epoch(2) - Loss: 1.4802, Acc: 46.1028
# 		 Validation(2) - Loss: 2.4276, Acc: 25.7576
# 		 Training: Epoch(3) - Loss: 1.2243, Acc: 56.0531
# 		 Validation(3) - Loss: 1.8812, Acc: 40.9091
# 		 Training: Epoch(4) - Loss: 1.0157, Acc: 63.5158
# 		 Validation(4) - Loss: 1.8734, Acc: 34.8485
# 		 Training: Epoch(5) - Loss: 0.8455, Acc: 69.3201
# 		 Validation(5) - Loss: 1.2561, Acc: 59.0909
# 		 Training: Epoch(6) - Loss: 0.8808, Acc: 70.8126
# 		 Validation(6) - Loss: 1.8425, Acc: 39.3939
# 		 Training: Epoch(7) - Loss: 0.8369, Acc: 69.8176
# 		 Validation(7) - Loss: 1.3500, Acc: 54.5455
# 		 Training: Epoch(8) - Loss: 0.6115, Acc: 76.7828
# 		 Validation(8) - Loss: 1.0752, Acc: 74.2424
# 		 Training: Epoch(9) - Loss: 0.6454, Acc: 76.6169
# 		 Validation(9) - Loss: 1.7405, Acc: 46.9697
# 		 Training: Epoch(10) - Loss: 0.5019, Acc: 82.4212
# 		 Validation(10) - Loss: 1.1558, Acc: 71.2121
# 		 Training: Epoch(11) - Loss: 0.3715, Acc: 88.3914
# 		 Validation(11) - Loss: 0.8904, Acc: 68.1818
# 		 Training: Epoch(12) - Loss: 0.3132, Acc: 89.5522
# 		 Validation(12) - Loss: 1.5809, Acc: 54.5455
# 		 Training: Epoch(13) - Loss: 0.2625, Acc: 90.8789
# 		 Validation(13) - Loss: 0.8619, Acc: 69.6970
# 		 Training: Epoch(14) - Loss: 0.3156, Acc: 90.2156
# 		 Validation(14) - Loss: 0.9192, Acc: 65.1515
# 		 Training: Epoch(15) - Loss: 0.2515, Acc: 93.2007
# 		 Validation(15) - Loss: 1.3861, Acc: 62.1212
# 		 Training: Epoch(16) - Loss: 0.3761, Acc: 88.0597
# 		 Validation(16) - Loss: 1.4919, Acc: 53.0303
# 		 Training: Epoch(17) - Loss: 0.2420, Acc: 93.6982
# 		 Validation(17) - Loss: 0.9513, Acc: 72.7273
# 		 Training: Epoch(18) - Loss: 0.1796, Acc: 95.5224
# 		 Validation(18) - Loss: 1.3172, Acc: 62.1212
# 		 Training: Epoch(19) - Loss: 0.2205, Acc: 92.7032
# 		 Validation(19) - Loss: 1.2800, Acc: 60.6061
# Finished.
# Total time per fold: 444.99173617362976 seconds.

# %%
print("Train accuracy average: ", np.mean(train_acc) / 100)
print("Top-1 test accuracy average: ", np.mean(test_top1_acc))
print("Top-5 test accuracy average: ", np.mean(test_top5_acc))
print("Weighted Precision test accuracy average: ", np.mean(test_precision))
print("Weighted Recall test accuracy average: ", np.mean(test_recall))
print("Weighted F1 test accuracy average: ", np.mean(test_f1))
print("Average time per fold (seconds):", np.mean(times))
# Out:
# Train accuracy average:  0.720915742439519
# Top-1 test accuracy average:  0.6307553143374038
# Top-5 test accuracy average:  0.9626865671641791
# Weighted Precision test accuracy average:  0.6846189382756547
# Weighted Recall test accuracy average:  0.6307553143374038
# Weighted F1 test accuracy average:  0.611132843110455
# Average time per fold (seconds): 444.8238146305084
