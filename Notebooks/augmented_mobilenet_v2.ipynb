# %% [markdown]
# # Code for the paper:
#
# ## Efficient and Mobile Deep Learning Architectures for Fast Identification of BacterialStrains in Resource-Constrained Devices
#
# ### Architecture: MobileNet v2
# ### Data: Augmented + Cross-Validation

# %% [markdown]
# #### Loading libraries

# %%
# Imports here
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import torch.nn.functional as F
import pandas as pd
import time
import numpy as np

from PIL import Image
from sklearn.metrics import f1_score, precision_score, recall_score, classification_report
from sklearn.model_selection import KFold
from torch import nn
from torch import optim
from torch.utils.data import SubsetRandomSampler
from torchvision import datasets, transforms, models
from pytorch_model_summary import summary

# Archs not in Pytorch
from efficientnet_pytorch import EfficientNet

# External functions
from scripts.utils import *

# %%
print(torch.__version__)

import sys
print(sys.version)
# Out:
# 1.5.1
# 3.8.5 (default, Jul 28 2020, 12:59:40)
# [GCC 9.3.0]

# %% [markdown]
# ## Data paths and hyperparameters

# %% [markdown]
# #### Hyperparameters and dataset details.

# %%
# Dataset details
dataset_version = 'original' # original or augmented
img_shape = (224,224)
img_size = str(img_shape[0])+"x"+str(img_shape[1])

# Root directory of dataset
data_dir = '/home/yibbtstll/venvs/pytorch_gpu/CySDeepBacterial/Dataset/DIBaS_augmented/'

train_batch_size = 64
val_test_batch_size = 32
feature_extract = False
pretrained = True
h_epochs = 15
kfolds = 10

# %% [markdown]
# ## Data preparation and loading

# %% [markdown]
# #### Defining transforms and creating dataloaders

# %%
# Define transforms for input data
training_transforms = transforms.Compose([transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406], 
                                                               [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
total_set = datasets.ImageFolder(data_dir, transform=training_transforms)

# Defining folds
splits = KFold(n_splits = kfolds, shuffle = True, random_state = 42)

# %% [markdown]
# #### Visualizing the target classes in dataset

# %%
train_labels = {value : key for (key, value) in total_set.class_to_idx.items()}
    
print(len(train_labels)) 
print(train_labels)
# Out:
# 32
# {0: 'Acinetobacter.baumanii', 1: 'Actinomyces.israeli', 2: 'Bacteroides.fragilis', 3: 'Bifidobacterium.spp', 4: 'Clostridium.perfringens', 5: 'Enterococcus.faecalis', 6: 'Enterococcus.faecium', 7: 'Escherichia.coli', 8: 'Fusobacterium', 9: 'Lactobacillus.casei', 10: 'Lactobacillus.crispatus', 11: 'Lactobacillus.delbrueckii', 12: 'Lactobacillus.gasseri', 13: 'Lactobacillus.jehnsenii', 14: 'Lactobacillus.johnsonii', 15: 'Lactobacillus.paracasei', 16: 'Lactobacillus.plantarum', 17: 'Lactobacillus.reuteri', 18: 'Lactobacillus.rhamnosus', 19: 'Lactobacillus.salivarius', 20: 'Listeria.monocytogenes', 21: 'Micrococcus.spp', 22: 'Neisseria.gonorrhoeae', 23: 'Porfyromonas.gingivalis', 24: 'Propionibacterium.acnes', 25: 'Proteus', 26: 'Pseudomonas.aeruginosa', 27: 'Staphylococcus.aureus', 28: 'Staphylococcus.epidermidis', 29: 'Staphylococcus.saprophiticus', 30: 'Streptococcus.agalactiae', 31: 'Veionella'}

# %% [markdown]
# ## Model definition and inicialization

# %% [markdown]
# #### Freezing pre-trained parameters, finetunning the classifier to output 32 classes.

# %%
# Freeze pretrained model parameters to avoid backpropogating through them
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        print("Setting grad to false.")
        for param in model.parameters():
            param.requires_grad = False
    
    return model

def get_device():
    # Model and criterion to GPU
    if torch.cuda.is_available():
        return 'cuda'
    else:
        return 'cpu'

# %%
models.mobilenet_v2(pretrained=False)
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): ConvBNReLU(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): ConvBNReLU(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
def load_model():
    # Transfer Learning
    model = models.mobilenet_v2(pretrained=pretrained)
    
    # Mode
    model = set_parameter_requires_grad(model, feature_extract)
    
    # Fine tuning
    # Build custom classifier
    model.classifier[1] = nn.Linear(in_features=1280,
                        out_features=32)
    return model

def create_optimizer(model):
    # Parameters to update
    params_to_update = model.parameters()

    if feature_extract:
        params_to_update = []
        for param in model.parameters():
            if param.requires_grad == True:
                params_to_update.append(param)

    else:
        n_params = 0
        for param in model.parameters():
            if param.requires_grad == True:
                n_params += 1


    # Loss function and gradient descent

    criterion = nn.CrossEntropyLoss()

    optimizer = optim.Adam(params_to_update, 
                          lr=0.0001, 
                          weight_decay=0.000004)
    
    return criterion.to(get_device()), model.to(get_device()), optimizer

# %% [markdown]
# ## Training, validation and test functions

# %%
# Variables to store fold scores
train_acc = []
test_top1_acc = []
test_top5_acc = []
test_precision = []
test_recall = []
test_f1 = []
times = []

for fold, (train_idx, valid_idx) in enumerate(splits.split(total_set)):
    
    start_time = time.time()
    
    print('Fold : {}'.format(fold))
    
    # Train and val samplers
    train_sampler = SubsetRandomSampler(train_idx)
    print("Samples in training:", len(train_sampler))
    valid_sampler = SubsetRandomSampler(valid_idx)
    print("Samples in test:", len(valid_sampler))
    
    # Train and val loaders
    train_loader = torch.utils.data.DataLoader(
                      total_set, batch_size=train_batch_size, sampler=train_sampler)
    valid_loader = torch.utils.data.DataLoader(
                      total_set, batch_size=1, sampler=valid_sampler)
    
    device = get_device()
    
    criterion, model, optimizer = create_optimizer(load_model())
    
    # Training
    for epoch in range(h_epochs):
        
        model.train()
        running_loss = 0.0
        running_corrects = 0
        trunning_corrects = 0
        
        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            
            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                
            running_loss += loss.item() * inputs.size(0)
            running_corrects += (preds == labels).sum()
            trunning_corrects += preds.size(0)
            

        epoch_loss = running_loss / trunning_corrects
        epoch_acc = (running_corrects.double()*100) / trunning_corrects
        train_acc.append(epoch_acc.item())
        
        print('\t\t Training: Epoch({}) - Loss: {:.4f}, Acc: {:.4f}'.format(epoch, epoch_loss, epoch_acc))
        
        # Validation
        
        model.eval()  
        
        vrunning_loss = 0.0
        vrunning_corrects = 0
        num_samples = 0
        
        for data, labels in valid_loader:
            
            data = data.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            
            with torch.no_grad():
                outputs = model(data)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                
            vrunning_loss += loss.item() * data.size(0)
            vrunning_corrects += (preds == labels).sum()
            num_samples += preds.size(0)
            
        vepoch_loss = vrunning_loss/num_samples
        vepoch_acc = (vrunning_corrects.double() * 100)/num_samples
        
        print('\t\t Validation({}) - Loss: {:.4f}, Acc: {:.4f}'.format(epoch, vepoch_loss, vepoch_acc))
    
    # Calculating and appending scores to this fold
    model.class_to_idx = total_set.class_to_idx
    scores = get_scores(model, valid_loader)
    
    test_top1_acc.append(scores[0])
    test_top5_acc.append(scores[1])
    test_precision.append(scores[2])
    test_recall.append(scores[3])
    test_f1.append(scores[4])
    
    time_fold = time.time() - start_time
    times.append(time_fold)
    print("Total time per fold: %s seconds." %(time_fold))
# Out:
# Fold : 0
# Samples in training: 21665
# Samples in test: 2408
# 		 Training: Epoch(0) - Loss: 0.6470, Acc: 83.8634
# 		 Validation(0) - Loss: 0.2120, Acc: 93.7708
# 		 Training: Epoch(1) - Loss: 0.1727, Acc: 94.7658
# 		 Validation(1) - Loss: 0.1459, Acc: 95.2658
# 		 Training: Epoch(2) - Loss: 0.1235, Acc: 96.2059
# 		 Validation(2) - Loss: 0.1102, Acc: 96.4701
# 		 Training: Epoch(3) - Loss: 0.0879, Acc: 97.3321
# 		 Validation(3) - Loss: 0.1022, Acc: 96.5532
# 		 Training: Epoch(4) - Loss: 0.0685, Acc: 97.9275
# 		 Validation(4) - Loss: 0.0951, Acc: 96.8854
# 		 Training: Epoch(5) - Loss: 0.0568, Acc: 98.2137
# 		 Validation(5) - Loss: 0.0930, Acc: 96.9684
# 		 Training: Epoch(6) - Loss: 0.0552, Acc: 98.2829
# 		 Validation(6) - Loss: 0.0936, Acc: 96.9684
# 		 Training: Epoch(7) - Loss: 0.0416, Acc: 98.7907
# 		 Validation(7) - Loss: 0.0724, Acc: 97.8821
# 		 Training: Epoch(8) - Loss: 0.0405, Acc: 98.8461
# 		 Validation(8) - Loss: 0.1028, Acc: 96.9684
# 		 Training: Epoch(9) - Loss: 0.0342, Acc: 98.9245
# 		 Validation(9) - Loss: 0.0981, Acc: 97.3837
# 		 Training: Epoch(10) - Loss: 0.0294, Acc: 99.1415
# 		 Validation(10) - Loss: 0.0915, Acc: 97.3007
# 		 Training: Epoch(11) - Loss: 0.0308, Acc: 99.0122
# 		 Validation(11) - Loss: 0.0934, Acc: 97.4668
# 		 Training: Epoch(12) - Loss: 0.0314, Acc: 98.9568
# 		 Validation(12) - Loss: 0.0877, Acc: 97.7159
# 		 Training: Epoch(13) - Loss: 0.0171, Acc: 99.5338
# 		 Validation(13) - Loss: 0.0811, Acc: 97.8821
# 		 Training: Epoch(14) - Loss: 0.0221, Acc: 99.3676
# 		 Validation(14) - Loss: 0.1082, Acc: 97.0100
# Finished.
# Total time per fold: 2352.2927072048187 seconds.
# Fold : 1
# Samples in training: 21665
# Samples in test: 2408
# 		 Training: Epoch(0) - Loss: 0.6649, Acc: 83.4480
# 		 Validation(0) - Loss: 0.1812, Acc: 94.9336
# 		 Training: Epoch(1) - Loss: 0.1730, Acc: 94.8535
# 		 Validation(1) - Loss: 0.1374, Acc: 95.5565
# 		 Training: Epoch(2) - Loss: 0.1103, Acc: 96.6120
# 		 Validation(2) - Loss: 0.1032, Acc: 96.5947
# 		 Training: Epoch(3) - Loss: 0.0928, Acc: 97.1521
# 		 Validation(3) - Loss: 0.1008, Acc: 96.7608
# 		 Training: Epoch(4) - Loss: 0.0704, Acc: 97.8906
# 		 Validation(4) - Loss: 0.0988, Acc: 96.7608
# 		 Training: Epoch(5) - Loss: 0.0568, Acc: 98.2922
# 		 Validation(5) - Loss: 0.1062, Acc: 96.7608
# 		 Training: Epoch(6) - Loss: 0.0472, Acc: 98.4999
# 		 Validation(6) - Loss: 0.0800, Acc: 97.3422
# 		 Training: Epoch(7) - Loss: 0.0432, Acc: 98.7168
# 		 Validation(7) - Loss: 0.0919, Acc: 97.2176
# 		 Training: Epoch(8) - Loss: 0.0336, Acc: 99.0307
# 		 Validation(8) - Loss: 0.0885, Acc: 97.0515
# 		 Training: Epoch(9) - Loss: 0.0364, Acc: 98.9522
# 		 Validation(9) - Loss: 0.1230, Acc: 96.5532
# 		 Training: Epoch(10) - Loss: 0.0376, Acc: 98.8461
# 		 Validation(10) - Loss: 0.0842, Acc: 97.0100
# 		 Training: Epoch(11) - Loss: 0.0266, Acc: 99.2292
# 		 Validation(11) - Loss: 0.0830, Acc: 97.3422
# 		 Training: Epoch(12) - Loss: 0.0222, Acc: 99.3215
# 		 Validation(12) - Loss: 0.0759, Acc: 97.7575
# 		 Training: Epoch(13) - Loss: 0.0280, Acc: 99.1369
# 		 Validation(13) - Loss: 0.1274, Acc: 96.5116
# 		 Training: Epoch(14) - Loss: 0.0281, Acc: 99.1830
# 		 Validation(14) - Loss: 0.0938, Acc: 97.3422
# Finished.
# Total time per fold: 1831.013179063797 seconds.
# Fold : 2
# Samples in training: 21665
# Samples in test: 2408
# 		 Training: Epoch(0) - Loss: 0.6669, Acc: 83.5357
# 		 Validation(0) - Loss: 0.1810, Acc: 94.5183
# 		 Training: Epoch(1) - Loss: 0.1726, Acc: 94.9873
# 		 Validation(1) - Loss: 0.1252, Acc: 95.8887
# 		 Training: Epoch(2) - Loss: 0.1152, Acc: 96.4551
# 		 Validation(2) - Loss: 0.1215, Acc: 96.0963
# 		 Training: Epoch(3) - Loss: 0.0901, Acc: 97.1890
# 		 Validation(3) - Loss: 0.0939, Acc: 96.8439
# 		 Training: Epoch(4) - Loss: 0.0654, Acc: 98.0660
# 		 Validation(4) - Loss: 0.0830, Acc: 97.1761
# 		 Training: Epoch(5) - Loss: 0.0617, Acc: 98.0660
# 		 Validation(5) - Loss: 0.0916, Acc: 96.6777
# 		 Training: Epoch(6) - Loss: 0.0461, Acc: 98.5230
# 		 Validation(6) - Loss: 0.0808, Acc: 97.4668
# 		 Training: Epoch(7) - Loss: 0.0448, Acc: 98.6476
# 		 Validation(7) - Loss: 0.0923, Acc: 96.8439
# 		 Training: Epoch(8) - Loss: 0.0387, Acc: 98.7307
# 		 Validation(8) - Loss: 0.0770, Acc: 97.4252
# 		 Training: Epoch(9) - Loss: 0.0302, Acc: 99.1599
# 		 Validation(9) - Loss: 0.0836, Acc: 97.3422
# 		 Training: Epoch(10) - Loss: 0.0325, Acc: 99.0168
# 		 Validation(10) - Loss: 0.1237, Acc: 96.0548
# 		 Training: Epoch(11) - Loss: 0.0285, Acc: 99.0815
# 		 Validation(11) - Loss: 0.1052, Acc: 96.8439
# 		 Training: Epoch(12) - Loss: 0.0346, Acc: 98.9153
# 		 Validation(12) - Loss: 0.0917, Acc: 97.4668
# 		 Training: Epoch(13) - Loss: 0.0245, Acc: 99.2753
# 		 Validation(13) - Loss: 0.1005, Acc: 97.1761
# 		 Training: Epoch(14) - Loss: 0.0219, Acc: 99.3353
# 		 Validation(14) - Loss: 0.0870, Acc: 97.5498
# Finished.
# Total time per fold: 1782.195856809616 seconds.
# Fold : 3
# Samples in training: 21666
# Samples in test: 2407
# 		 Training: Epoch(0) - Loss: 0.6676, Acc: 83.3610
# 		 Validation(0) - Loss: 0.1892, Acc: 94.6822
# 		 Training: Epoch(1) - Loss: 0.1770, Acc: 94.8721
# 		 Validation(1) - Loss: 0.1243, Acc: 95.8870
# 		 Training: Epoch(2) - Loss: 0.1130, Acc: 96.6676
# 		 Validation(2) - Loss: 0.1037, Acc: 96.8010
# 		 Training: Epoch(3) - Loss: 0.0932, Acc: 97.0507
# 		 Validation(3) - Loss: 0.0871, Acc: 97.1749
# 		 Training: Epoch(4) - Loss: 0.0694, Acc: 97.8769
# 		 Validation(4) - Loss: 0.0971, Acc: 97.1334
# 		 Training: Epoch(5) - Loss: 0.0585, Acc: 98.2599
# 		 Validation(5) - Loss: 0.0844, Acc: 97.0503
# 		 Training: Epoch(6) - Loss: 0.0492, Acc: 98.4584
# 		 Validation(6) - Loss: 0.0957, Acc: 97.1749
# 		 Training: Epoch(7) - Loss: 0.0422, Acc: 98.7492
# 		 Validation(7) - Loss: 0.0885, Acc: 97.2165
# 		 Training: Epoch(8) - Loss: 0.0398, Acc: 98.7815
# 		 Validation(8) - Loss: 0.0789, Acc: 97.7150
# 		 Training: Epoch(9) - Loss: 0.0405, Acc: 98.8277
# 		 Validation(9) - Loss: 0.1018, Acc: 97.1334
# 		 Training: Epoch(10) - Loss: 0.0312, Acc: 99.0815
# 		 Validation(10) - Loss: 0.0961, Acc: 97.4242
# 		 Training: Epoch(11) - Loss: 0.0286, Acc: 99.0492
# 		 Validation(11) - Loss: 0.1074, Acc: 96.6764
# 		 Training: Epoch(12) - Loss: 0.0279, Acc: 99.1369
# 		 Validation(12) - Loss: 0.0933, Acc: 96.9672
# 		 Training: Epoch(13) - Loss: 0.0202, Acc: 99.4000
# 		 Validation(13) - Loss: 0.1190, Acc: 96.8425
# 		 Training: Epoch(14) - Loss: 0.0355, Acc: 98.8507
# 		 Validation(14) - Loss: 0.0987, Acc: 97.2995
# Finished.
# Total time per fold: 1882.28045129776 seconds.
# Fold : 4
# Samples in training: 21666
# Samples in test: 2407
# 		 Training: Epoch(0) - Loss: 0.6518, Acc: 84.0118
# 		 Validation(0) - Loss: 0.1988, Acc: 93.5189
# 		 Training: Epoch(1) - Loss: 0.1780, Acc: 94.5814
# 		 Validation(1) - Loss: 0.1327, Acc: 96.0532
# 		 Training: Epoch(2) - Loss: 0.1142, Acc: 96.3860
# 		 Validation(2) - Loss: 0.1368, Acc: 95.7624
# 		 Training: Epoch(3) - Loss: 0.0874, Acc: 97.2815
# 		 Validation(3) - Loss: 0.0949, Acc: 96.4271
# 		 Training: Epoch(4) - Loss: 0.0675, Acc: 98.0338
# 		 Validation(4) - Loss: 0.0926, Acc: 96.8425
# 		 Training: Epoch(5) - Loss: 0.0550, Acc: 98.4169
# 		 Validation(5) - Loss: 0.1116, Acc: 96.3440
# 		 Training: Epoch(6) - Loss: 0.0479, Acc: 98.4907
# 		 Validation(6) - Loss: 0.1112, Acc: 96.4686
# 		 Training: Epoch(7) - Loss: 0.0465, Acc: 98.5784
# 		 Validation(7) - Loss: 0.1008, Acc: 96.8841
# 		 Training: Epoch(8) - Loss: 0.0437, Acc: 98.6015
# 		 Validation(8) - Loss: 0.1023, Acc: 96.9256
# 		 Training: Epoch(9) - Loss: 0.0371, Acc: 98.8969
# 		 Validation(9) - Loss: 0.0973, Acc: 96.9672
# 		 Training: Epoch(10) - Loss: 0.0331, Acc: 98.9707
# 		 Validation(10) - Loss: 0.1049, Acc: 96.9672
# 		 Training: Epoch(11) - Loss: 0.0288, Acc: 99.1277
# 		 Validation(11) - Loss: 0.1186, Acc: 96.8010
# 		 Training: Epoch(12) - Loss: 0.0324, Acc: 99.0077
# 		 Validation(12) - Loss: 0.1179, Acc: 96.4686
# 		 Training: Epoch(13) - Loss: 0.0253, Acc: 99.2384
# 		 Validation(13) - Loss: 0.1106, Acc: 97.0087
# 		 Training: Epoch(14) - Loss: 0.0189, Acc: 99.4831
# 		 Validation(14) - Loss: 0.1088, Acc: 97.3826
# Finished.
# Total time per fold: 1859.7578511238098 seconds.
# Fold : 5
# Samples in training: 21666
# Samples in test: 2407
# 		 Training: Epoch(0) - Loss: 0.6604, Acc: 83.4533
# 		 Validation(0) - Loss: 0.2204, Acc: 93.1865
# 		 Training: Epoch(1) - Loss: 0.1765, Acc: 94.7060
# 		 Validation(1) - Loss: 0.1615, Acc: 94.8484
# 		 Training: Epoch(2) - Loss: 0.1162, Acc: 96.4553
# 		 Validation(2) - Loss: 0.1222, Acc: 95.9285
# 		 Training: Epoch(3) - Loss: 0.0862, Acc: 97.4199
# 		 Validation(3) - Loss: 0.1223, Acc: 96.1363
# 		 Training: Epoch(4) - Loss: 0.0711, Acc: 97.9322
# 		 Validation(4) - Loss: 0.1276, Acc: 96.1778
# 		 Training: Epoch(5) - Loss: 0.0623, Acc: 98.1030
# 		 Validation(5) - Loss: 0.1176, Acc: 96.0532
# 		 Training: Epoch(6) - Loss: 0.0437, Acc: 98.7077
# 		 Validation(6) - Loss: 0.0903, Acc: 96.7179
# 		 Training: Epoch(7) - Loss: 0.0475, Acc: 98.5415
# 		 Validation(7) - Loss: 0.1254, Acc: 96.3855
# 		 Training: Epoch(8) - Loss: 0.0355, Acc: 98.9015
# 		 Validation(8) - Loss: 0.1229, Acc: 96.0532
# 		 Training: Epoch(9) - Loss: 0.0268, Acc: 99.2154
# 		 Validation(9) - Loss: 0.1176, Acc: 96.3025
# 		 Training: Epoch(10) - Loss: 0.0322, Acc: 99.0261
# 		 Validation(10) - Loss: 0.1323, Acc: 96.0532
# 		 Training: Epoch(11) - Loss: 0.0362, Acc: 98.9430
# 		 Validation(11) - Loss: 0.1049, Acc: 96.6764
# 		 Training: Epoch(12) - Loss: 0.0225, Acc: 99.2800
# 		 Validation(12) - Loss: 0.1360, Acc: 96.1363
# 		 Training: Epoch(13) - Loss: 0.0328, Acc: 98.9661
# 		 Validation(13) - Loss: 0.1039, Acc: 96.7179
# 		 Training: Epoch(14) - Loss: 0.0168, Acc: 99.5200
# 		 Validation(14) - Loss: 0.0944, Acc: 97.1749
# Finished.
# Total time per fold: 1844.0174796581268 seconds.
# Fold : 6
# Samples in training: 21666
# Samples in test: 2407
# 		 Training: Epoch(0) - Loss: 0.6776, Acc: 82.9964
# 		 Validation(0) - Loss: 0.1896, Acc: 94.3083
# 		 Training: Epoch(1) - Loss: 0.1749, Acc: 94.9414
# 		 Validation(1) - Loss: 0.1367, Acc: 95.8455
# 		 Training: Epoch(2) - Loss: 0.1154, Acc: 96.5799
# 		 Validation(2) - Loss: 0.1164, Acc: 96.4271
# 		 Training: Epoch(3) - Loss: 0.0903, Acc: 97.2399
# 		 Validation(3) - Loss: 0.1083, Acc: 96.5517
# 		 Training: Epoch(4) - Loss: 0.0717, Acc: 97.8030
# 		 Validation(4) - Loss: 0.0932, Acc: 96.9256
# 		 Training: Epoch(5) - Loss: 0.0575, Acc: 98.2692
# 		 Validation(5) - Loss: 0.0777, Acc: 97.3826
# 		 Training: Epoch(6) - Loss: 0.0531, Acc: 98.3707
# 		 Validation(6) - Loss: 0.0748, Acc: 97.6319
# 		 Training: Epoch(7) - Loss: 0.0416, Acc: 98.7630
# 		 Validation(7) - Loss: 0.0793, Acc: 97.0918
# 		 Training: Epoch(8) - Loss: 0.0315, Acc: 99.0400
# 		 Validation(8) - Loss: 0.0982, Acc: 97.2995
# 		 Training: Epoch(9) - Loss: 0.0352, Acc: 98.9615
# 		 Validation(9) - Loss: 0.1152, Acc: 96.3440
# 		 Training: Epoch(10) - Loss: 0.0338, Acc: 98.9984
# 		 Validation(10) - Loss: 0.0970, Acc: 96.8010
# 		 Training: Epoch(11) - Loss: 0.0315, Acc: 99.0538
# 		 Validation(11) - Loss: 0.0854, Acc: 97.3411
# 		 Training: Epoch(12) - Loss: 0.0232, Acc: 99.3584
# 		 Validation(12) - Loss: 0.0746, Acc: 97.7981
# 		 Training: Epoch(13) - Loss: 0.0255, Acc: 99.2338
# 		 Validation(13) - Loss: 0.1094, Acc: 96.9672
# 		 Training: Epoch(14) - Loss: 0.0273, Acc: 99.2246
# 		 Validation(14) - Loss: 0.0914, Acc: 97.2165
# Finished.
# Total time per fold: 1832.2962656021118 seconds.
# Fold : 7
# Samples in training: 21666
# Samples in test: 2407
# 		 Training: Epoch(0) - Loss: 0.6497, Acc: 84.1272
# 		 Validation(0) - Loss: 0.1935, Acc: 93.9344
# 		 Training: Epoch(1) - Loss: 0.1722, Acc: 94.9183
# 		 Validation(1) - Loss: 0.1318, Acc: 95.9701
# 		 Training: Epoch(2) - Loss: 0.1172, Acc: 96.3722
# 		 Validation(2) - Loss: 0.1168, Acc: 96.3025
# 		 Training: Epoch(3) - Loss: 0.0871, Acc: 97.3045
# 		 Validation(3) - Loss: 0.1073, Acc: 96.6348
# 		 Training: Epoch(4) - Loss: 0.0691, Acc: 97.8538
# 		 Validation(4) - Loss: 0.0965, Acc: 96.8010
# 		 Training: Epoch(5) - Loss: 0.0570, Acc: 98.2323
# 		 Validation(5) - Loss: 0.1176, Acc: 96.6348
# 		 Training: Epoch(6) - Loss: 0.0468, Acc: 98.5692
# 		 Validation(6) - Loss: 0.1280, Acc: 96.1363
# 		 Training: Epoch(7) - Loss: 0.0417, Acc: 98.7169
# 		 Validation(7) - Loss: 0.1018, Acc: 96.6764
# 		 Training: Epoch(8) - Loss: 0.0361, Acc: 98.9661
# 		 Validation(8) - Loss: 0.1053, Acc: 96.5517
# 		 Training: Epoch(9) - Loss: 0.0403, Acc: 98.7353
# 		 Validation(9) - Loss: 0.0999, Acc: 97.0087
# 		 Training: Epoch(10) - Loss: 0.0343, Acc: 98.9246
# 		 Validation(10) - Loss: 0.1214, Acc: 95.7624
# 		 Training: Epoch(11) - Loss: 0.0326, Acc: 99.0400
# 		 Validation(11) - Loss: 0.1229, Acc: 96.3855
# 		 Training: Epoch(12) - Loss: 0.0251, Acc: 99.2892
# 		 Validation(12) - Loss: 0.0941, Acc: 97.3411
# 		 Training: Epoch(13) - Loss: 0.0226, Acc: 99.3354
# 		 Validation(13) - Loss: 0.0997, Acc: 96.8841
# 		 Training: Epoch(14) - Loss: 0.0236, Acc: 99.2892
# 		 Validation(14) - Loss: 0.1276, Acc: 96.9256
# Finished.
# Total time per fold: 1849.229466676712 seconds.
# Fold : 8
# Samples in training: 21666
# Samples in test: 2407
# 		 Training: Epoch(0) - Loss: 0.6645, Acc: 83.8364
# 		 Validation(0) - Loss: 0.1669, Acc: 95.3054
# 		 Training: Epoch(1) - Loss: 0.1758, Acc: 94.6783
# 		 Validation(1) - Loss: 0.1140, Acc: 96.5517
# 		 Training: Epoch(2) - Loss: 0.1195, Acc: 96.1553
# 		 Validation(2) - Loss: 0.1577, Acc: 94.9314
# 		 Training: Epoch(3) - Loss: 0.0910, Acc: 97.2122
# 		 Validation(3) - Loss: 0.0961, Acc: 96.9256
# 		 Training: Epoch(4) - Loss: 0.0738, Acc: 97.6738
# 		 Validation(4) - Loss: 0.0907, Acc: 96.7179
# 		 Training: Epoch(5) - Loss: 0.0578, Acc: 98.2738
# 		 Validation(5) - Loss: 0.0903, Acc: 96.8425
# 		 Training: Epoch(6) - Loss: 0.0500, Acc: 98.4907
# 		 Validation(6) - Loss: 0.0750, Acc: 97.8396
# 		 Training: Epoch(7) - Loss: 0.0445, Acc: 98.6200
# 		 Validation(7) - Loss: 0.0908, Acc: 96.8425
# 		 Training: Epoch(8) - Loss: 0.0418, Acc: 98.7492
# 		 Validation(8) - Loss: 0.0759, Acc: 97.2580
# 		 Training: Epoch(9) - Loss: 0.0334, Acc: 98.9430
# 		 Validation(9) - Loss: 0.0834, Acc: 97.1749
# 		 Training: Epoch(10) - Loss: 0.0330, Acc: 98.8692
# 		 Validation(10) - Loss: 0.0868, Acc: 97.0918
# 		 Training: Epoch(11) - Loss: 0.0320, Acc: 99.0907
# 		 Validation(11) - Loss: 0.0924, Acc: 97.4242
# 		 Training: Epoch(12) - Loss: 0.0258, Acc: 99.1877
# 		 Validation(12) - Loss: 0.0823, Acc: 97.3411
# 		 Training: Epoch(13) - Loss: 0.0247, Acc: 99.2569
# 		 Validation(13) - Loss: 0.0685, Acc: 97.8396
# 		 Training: Epoch(14) - Loss: 0.0240, Acc: 99.2846
# 		 Validation(14) - Loss: 0.0807, Acc: 97.6735
# Finished.
# Total time per fold: 1828.8490233421326 seconds.
# Fold : 9
# Samples in training: 21666
# Samples in test: 2407
# 		 Training: Epoch(0) - Loss: 0.6614, Acc: 83.5180
# 		 Validation(0) - Loss: 0.1705, Acc: 94.8068
# 		 Training: Epoch(1) - Loss: 0.1753, Acc: 94.7891
# 		 Validation(1) - Loss: 0.1180, Acc: 96.3855
# 		 Training: Epoch(2) - Loss: 0.1162, Acc: 96.3583
# 		 Validation(2) - Loss: 0.0985, Acc: 96.4686
# 		 Training: Epoch(3) - Loss: 0.0960, Acc: 96.9491
# 		 Validation(3) - Loss: 0.0822, Acc: 97.3411
# 		 Training: Epoch(4) - Loss: 0.0693, Acc: 97.8030
# 		 Validation(4) - Loss: 0.0948, Acc: 97.0918
# 		 Training: Epoch(5) - Loss: 0.0535, Acc: 98.4076
# 		 Validation(5) - Loss: 0.0802, Acc: 97.3826
# 		 Training: Epoch(6) - Loss: 0.0524, Acc: 98.3846
# 		 Validation(6) - Loss: 0.0796, Acc: 97.2995
# 		 Training: Epoch(7) - Loss: 0.0430, Acc: 98.6384
# 		 Validation(7) - Loss: 0.0743, Acc: 97.6735
# 		 Training: Epoch(8) - Loss: 0.0407, Acc: 98.8323
# 		 Validation(8) - Loss: 0.0802, Acc: 97.6319
# 		 Training: Epoch(9) - Loss: 0.0390, Acc: 98.8092
# 		 Validation(9) - Loss: 0.0753, Acc: 97.5073
# 		 Training: Epoch(10) - Loss: 0.0288, Acc: 99.1507
# 		 Validation(10) - Loss: 0.0703, Acc: 97.7981
# 		 Training: Epoch(11) - Loss: 0.0301, Acc: 99.0861
# 		 Validation(11) - Loss: 0.0947, Acc: 97.1334
# 		 Training: Epoch(12) - Loss: 0.0248, Acc: 99.2477
# 		 Validation(12) - Loss: 0.0882, Acc: 97.1749
# 		 Training: Epoch(13) - Loss: 0.0299, Acc: 99.0354
# 		 Validation(13) - Loss: 0.0983, Acc: 96.6348
# 		 Training: Epoch(14) - Loss: 0.0254, Acc: 99.1969
# 		 Validation(14) - Loss: 0.0726, Acc: 98.1305
# Finished.
# Total time per fold: 1841.1541097164154 seconds.

# %%
print("Train accuracy average: ", np.mean(train_acc) / 100)
print("Top-1 test accuracy average: ", np.mean(test_top1_acc))
print("Top-5 test accuracy average: ", np.mean(test_top5_acc))
print("Weighted Precision test accuracy average: ", np.mean(test_precision))
print("Weighted Recall test accuracy average: ", np.mean(test_recall))
print("Weighted F1 test accuracy average: ", np.mean(test_f1))
print("Average time per fold (seconds):", np.mean(times))
# Out:
# Train accuracy average:  0.9726033949156576
# Top-1 test accuracy average:  0.9737050677219129
# Top-5 test accuracy average:  0.9980476551641322
# Weighted Precision test accuracy average:  0.9745395342818475
# Weighted Recall test accuracy average:  0.9737050677219129
# Weighted F1 test accuracy average:  0.9737415427536854
# Average time per fold (seconds): 1890.30863904953
